# %% [markdown]
# <a href="https://colab.research.google.com/github/moneshj/Cow-classification/blob/main/Plastics_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Reference Paper's :
#
#
# *   https://www.researchgate.net/publication/351797845_Detection_of_Plastic_Greenhouses_Using_High_Resolution_Rgb_Remote_Sensing_Data_and_Convolutional_Neural_Network
# *  https://www.sciencedirect.com/science/article/pii/S0303243421001483

# %% [markdown]
# #Plastic :1  antiplasti/Plastic-Detection-Model

# %%
# !git clone https://github.com/antiplasti/Plastic-Detection-Model.git
# Out:
# Cloning into 'Plastic-Detection-Model'...
# remote: Enumerating objects: 119, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 119 (delta 0), reused 1 (delta 0), pack-reused 115
# Receiving objects: 100% (119/119), 42.76 MiB | 34.18 MiB/s, done.
# Resolving deltas: 100% (61/61), done.

# %%
# !unzip /content/Plastic-Detection-Model/training_dataset.zip

# %%
# !/content/Plastic-Detection-Model/train.sh
# Out:
# /bin/bash: /content/Plastic-Detection-Model/train.sh: Permission denied

# %%
cd Plastic-Detection-Model/
# Out:
# [Errno 2] No such file or directory: 'Plastic-Detection-Model/'
# /root

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import argparse
from datetime import datetime
import hashlib
import os.path
import random
import re
import struct
import sys
import tarfile

import numpy as np
from six.moves import urllib
import tensorflow as tf

from tensorflow.python.framework import graph_util
from tensorflow.python.framework import tensor_shape
from tensorflow.python.platform import gfile
from tensorflow.python.util import compat

FLAGS = None

# These are all parameters that are tied to the particular model architecture
# we're using for Inception v3. These include things like tensor names and their
# sizes. If you want to adapt this script to work with another model, you will
# need to update these to reflect the values in the network you're using.
# pylint: disable=line-too-long
DATA_URL = 'http://download.tensorflow.org/models/image/imagenet/inception-2015-12-05.tgz'
# pylint: enable=line-too-long
BOTTLENECK_TENSOR_NAME = 'pool_3/_reshape:0'
BOTTLENECK_TENSOR_SIZE = 2048
MODEL_INPUT_WIDTH = 299
MODEL_INPUT_HEIGHT = 299
MODEL_INPUT_DEPTH = 3
JPEG_DATA_TENSOR_NAME = 'DecodeJpeg/contents:0'
RESIZED_INPUT_TENSOR_NAME = 'ResizeBilinear:0'
MAX_NUM_IMAGES_PER_CLASS = 2 ** 27 - 1  # ~134M


def create_image_lists(image_dir, testing_percentage, validation_percentage):
  """Builds a list of training images from the file system.

  Analyzes the sub folders in the image directory, splits them into stable
  training, testing, and validation sets, and returns a data structure
  describing the lists of images for each label and their paths.

  Args:
    image_dir: String path to a folder containing subfolders of images.
    testing_percentage: Integer percentage of the images to reserve for tests.
    validation_percentage: Integer percentage of images reserved for validation.

  Returns:
    A dictionary containing an entry for each label subfolder, with images split
    into training, testing, and validation sets within each label.
  """
  if not gfile.Exists(image_dir):
    print("Image directory '" + image_dir + "' not found.")
    return None
  result = {}
  sub_dirs = [x[0] for x in gfile.Walk(image_dir)]
  # The root directory comes first, so skip it.
  is_root_dir = True
  for sub_dir in sub_dirs:
    if is_root_dir:
      is_root_dir = False
      continue
    extensions = ['jpg', 'jpeg', 'JPG', 'JPEG']
    file_list = []
    dir_name = os.path.basename(sub_dir)
    if dir_name == image_dir:
      continue
    print("Looking for images in '" + dir_name + "'")
    for extension in extensions:
      file_glob = os.path.join(image_dir, dir_name, '*.' + extension)
      file_list.extend(gfile.Glob(file_glob))
    if not file_list:
      print('No files found')
      continue
    if len(file_list) < 20:
      print('WARNING: Folder has less than 20 images, which may cause issues.')
    elif len(file_list) > MAX_NUM_IMAGES_PER_CLASS:
      print('WARNING: Folder {} has more than {} images. Some images will '
            'never be selected.'.format(dir_name, MAX_NUM_IMAGES_PER_CLASS))
    label_name = re.sub(r'[^a-z0-9]+', ' ', dir_name.lower())
    training_images = []
    testing_images = []
    validation_images = []
    for file_name in file_list:
      base_name = os.path.basename(file_name)
      # We want to ignore anything after '_nohash_' in the file name when
      # deciding which set to put an image in, the data set creator has a way of
      # grouping photos that are close variations of each other. For example
      # this is used in the plant disease data set to group multiple pictures of
      # the same leaf.
      hash_name = re.sub(r'_nohash_.*$', '', file_name)
      # This looks a bit magical, but we need to decide whether this file should
      # go into the training, testing, or validation sets, and we want to keep
      # existing files in the same set even if more files are subsequently
      # added.
      # To do that, we need a stable way of deciding based on just the file name
      # itself, so we do a hash of that and then use that to generate a
      # probability value that we use to assign it.
      hash_name_hashed = hashlib.sha1(compat.as_bytes(hash_name)).hexdigest()
      percentage_hash = ((int(hash_name_hashed, 16) %
                          (MAX_NUM_IMAGES_PER_CLASS + 1)) *
                         (100.0 / MAX_NUM_IMAGES_PER_CLASS))
      if percentage_hash < validation_percentage:
        validation_images.append(base_name)
      elif percentage_hash < (testing_percentage + validation_percentage):
        testing_images.append(base_name)
      else:
        training_images.append(base_name)
    result[label_name] = {
        'dir': dir_name,
        'training': training_images,
        'testing': testing_images,
        'validation': validation_images,
    }
  return result


def get_image_path(image_lists, label_name, index, image_dir, category):
  """"Returns a path to an image for a label at the given index.

  Args:
    image_lists: Dictionary of training images for each label.
    label_name: Label string we want to get an image for.
    index: Int offset of the image we want. This will be moduloed by the
    available number of images for the label, so it can be arbitrarily large.
    image_dir: Root folder string of the subfolders containing the training
    images.
    category: Name string of set to pull images from - training, testing, or
    validation.

  Returns:
    File system path string to an image that meets the requested parameters.

  """
  if label_name not in image_lists:
    tf.logging.fatal('Label does not exist %s.', label_name)
  label_lists = image_lists[label_name]
  if category not in label_lists:
    tf.logging.fatal('Category does not exist %s.', category)
  category_list = label_lists[category]
  if not category_list:
    tf.logging.fatal('Label %s has no images in the category %s.',
                     label_name, category)
  mod_index = index % len(category_list)
  base_name = category_list[mod_index]
  sub_dir = label_lists['dir']
  full_path = os.path.join(image_dir, sub_dir, base_name)
  return full_path


def get_bottleneck_path(image_lists, label_name, index, bottleneck_dir,
                        category):
  """"Returns a path to a bottleneck file for a label at the given index.

  Args:
    image_lists: Dictionary of training images for each label.
    label_name: Label string we want to get an image for.
    index: Integer offset of the image we want. This will be moduloed by the
    available number of images for the label, so it can be arbitrarily large.
    bottleneck_dir: Folder string holding cached files of bottleneck values.
    category: Name string of set to pull images from - training, testing, or
    validation.

  Returns:
    File system path string to an image that meets the requested parameters.
  """
  return get_image_path(image_lists, label_name, index, bottleneck_dir,
                        category) + '.txt'


def create_inception_graph():
  """"Creates a graph from saved GraphDef file and returns a Graph object.

  Returns:
    Graph holding the trained Inception network, and various tensors we'll be
    manipulating.
  """
  with tf.Graph().as_default() as graph:
    model_filename = os.path.join(
        FLAGS.model_dir, 'classify_image_graph_def.pb')
    with gfile.FastGFile(model_filename, 'rb') as f:
      graph_def = tf.GraphDef()
      graph_def.ParseFromString(f.read())
      bottleneck_tensor, jpeg_data_tensor, resized_input_tensor = (
          tf.import_graph_def(graph_def, name='', return_elements=[
              BOTTLENECK_TENSOR_NAME, JPEG_DATA_TENSOR_NAME,
              RESIZED_INPUT_TENSOR_NAME]))
  return graph, bottleneck_tensor, jpeg_data_tensor, resized_input_tensor


def run_bottleneck_on_image(sess, image_data, image_data_tensor,
                            bottleneck_tensor):
  """Runs inference on an image to extract the 'bottleneck' summary layer.

  Args:
    sess: Current active TensorFlow Session.
    image_data: String of raw JPEG data.
    image_data_tensor: Input data layer in the graph.
    bottleneck_tensor: Layer before the final softmax.

  Returns:
    Numpy array of bottleneck values.
  """
  bottleneck_values = sess.run(
      bottleneck_tensor,
      {image_data_tensor: image_data})
  bottleneck_values = np.squeeze(bottleneck_values)
  return bottleneck_values


def maybe_download_and_extract():
  """Download and extract model tar file.

  If the pretrained model we're using doesn't already exist, this function
  downloads it from the TensorFlow.org website and unpacks it into a directory.
  """
  dest_directory = FLAGS.model_dir
  if not os.path.exists(dest_directory):
    os.makedirs(dest_directory)
  filename = DATA_URL.split('/')[-1]
  filepath = os.path.join(dest_directory, filename)
  if not os.path.exists(filepath):

    def _progress(count, block_size, total_size):
      sys.stdout.write('\r>> Downloading %s %.1f%%' %
                       (filename,
                        float(count * block_size) / float(total_size) * 100.0))
      sys.stdout.flush()

    filepath, _ = urllib.request.urlretrieve(DATA_URL,
                                             filepath,
                                             _progress)
    print()
    statinfo = os.stat(filepath)
    print('Successfully downloaded', filename, statinfo.st_size, 'bytes.')
  tarfile.open(filepath, 'r:gz').extractall(dest_directory)


def ensure_dir_exists(dir_name):
  """Makes sure the folder exists on disk.

  Args:
    dir_name: Path string to the folder we want to create.
  """
  if not os.path.exists(dir_name):
    os.makedirs(dir_name)


def write_list_of_floats_to_file(list_of_floats, file_path):
  """Writes a given list of floats to a binary file.

  Args:
    list_of_floats: List of floats we want to write to a file.
    file_path: Path to a file where list of floats will be stored.

  """

  s = struct.pack('d' * BOTTLENECK_TENSOR_SIZE, *list_of_floats)
  with open(file_path, 'wb') as f:
    f.write(s)


def read_list_of_floats_from_file(file_path):
  """Reads list of floats from a given file.

  Args:
    file_path: Path to a file where list of floats was stored.
  Returns:
    Array of bottleneck values (list of floats).

  """

  with open(file_path, 'rb') as f:
    s = struct.unpack('d' * BOTTLENECK_TENSOR_SIZE, f.read())
    return list(s)


bottleneck_path_2_bottleneck_values = {}


def create_bottleneck_file(bottleneck_path, image_lists, label_name, index,
                           image_dir, category, sess, jpeg_data_tensor,
                           bottleneck_tensor):
  """Create a single bottleneck file."""
  print('Creating bottleneck at ' + bottleneck_path)
  image_path = get_image_path(image_lists, label_name, index,
                              image_dir, category)
  if not gfile.Exists(image_path):
    tf.logging.fatal('File does not exist %s', image_path)
  image_data = gfile.FastGFile(image_path, 'rb').read()
  try:
    bottleneck_values = run_bottleneck_on_image(
        sess, image_data, jpeg_data_tensor, bottleneck_tensor)
  except:
    raise RuntimeError('Error during processing file %s' % image_path)

  bottleneck_string = ','.join(str(x) for x in bottleneck_values)
  with open(bottleneck_path, 'w') as bottleneck_file:
    bottleneck_file.write(bottleneck_string)


def get_or_create_bottleneck(sess, image_lists, label_name, index, image_dir,
                             category, bottleneck_dir, jpeg_data_tensor,
                             bottleneck_tensor):
  """Retrieves or calculates bottleneck values for an image.

  If a cached version of the bottleneck data exists on-disk, return that,
  otherwise calculate the data and save it to disk for future use.

  Args:
    sess: The current active TensorFlow Session.
    image_lists: Dictionary of training images for each label.
    label_name: Label string we want to get an image for.
    index: Integer offset of the image we want. This will be modulo-ed by the
    available number of images for the label, so it can be arbitrarily large.
    image_dir: Root folder string  of the subfolders containing the training
    images.
    category: Name string of which  set to pull images from - training, testing,
    or validation.
    bottleneck_dir: Folder string holding cached files of bottleneck values.
    jpeg_data_tensor: The tensor to feed loaded jpeg data into.
    bottleneck_tensor: The output tensor for the bottleneck values.

  Returns:
    Numpy array of values produced by the bottleneck layer for the image.
  """
  label_lists = image_lists[label_name]
  sub_dir = label_lists['dir']
  sub_dir_path = os.path.join(bottleneck_dir, sub_dir)
  ensure_dir_exists(sub_dir_path)
  bottleneck_path = get_bottleneck_path(image_lists, label_name, index,
                                        bottleneck_dir, category)
  if not os.path.exists(bottleneck_path):
    create_bottleneck_file(bottleneck_path, image_lists, label_name, index,
                           image_dir, category, sess, jpeg_data_tensor,
                           bottleneck_tensor)
  with open(bottleneck_path, 'r') as bottleneck_file:
    bottleneck_string = bottleneck_file.read()
  did_hit_error = False
  try:
    bottleneck_values = [float(x) for x in bottleneck_string.split(',')]
  except ValueError:
    print('Invalid float found, recreating bottleneck')
    did_hit_error = True
  if did_hit_error:
    create_bottleneck_file(bottleneck_path, image_lists, label_name, index,
                           image_dir, category, sess, jpeg_data_tensor,
                           bottleneck_tensor)
    with open(bottleneck_path, 'r') as bottleneck_file:
      bottleneck_string = bottleneck_file.read()
    # Allow exceptions to propagate here, since they shouldn't happen after a
    # fresh creation
    bottleneck_values = [float(x) for x in bottleneck_string.split(',')]
  return bottleneck_values


def cache_bottlenecks(sess, image_lists, image_dir, bottleneck_dir,
                      jpeg_data_tensor, bottleneck_tensor):
  """Ensures all the training, testing, and validation bottlenecks are cached.

  Because we're likely to read the same image multiple times (if there are no
  distortions applied during training) it can speed things up a lot if we
  calculate the bottleneck layer values once for each image during
  preprocessing, and then just read those cached values repeatedly during
  training. Here we go through all the images we've found, calculate those
  values, and save them off.

  Args:
    sess: The current active TensorFlow Session.
    image_lists: Dictionary of training images for each label.
    image_dir: Root folder string of the subfolders containing the training
    images.
    bottleneck_dir: Folder string holding cached files of bottleneck values.
    jpeg_data_tensor: Input tensor for jpeg data from file.
    bottleneck_tensor: The penultimate output layer of the graph.

  Returns:
    Nothing.
  """
  how_many_bottlenecks = 0
  ensure_dir_exists(bottleneck_dir)
  for label_name, label_lists in image_lists.items():
    for category in ['training', 'testing', 'validation']:
      category_list = label_lists[category]
      for index, unused_base_name in enumerate(category_list):
        get_or_create_bottleneck(sess, image_lists, label_name, index,
                                 image_dir, category, bottleneck_dir,
                                 jpeg_data_tensor, bottleneck_tensor)

        how_many_bottlenecks += 1
        if how_many_bottlenecks % 100 == 0:
          print(str(how_many_bottlenecks) + ' bottleneck files created.')


def get_random_cached_bottlenecks(sess, image_lists, how_many, category,
                                  bottleneck_dir, image_dir, jpeg_data_tensor,
                                  bottleneck_tensor):
  """Retrieves bottleneck values for cached images.

  If no distortions are being applied, this function can retrieve the cached
  bottleneck values directly from disk for images. It picks a random set of
  images from the specified category.

  Args:
    sess: Current TensorFlow Session.
    image_lists: Dictionary of training images for each label.
    how_many: If positive, a random sample of this size will be chosen.
    If negative, all bottlenecks will be retrieved.
    category: Name string of which set to pull from - training, testing, or
    validation.
    bottleneck_dir: Folder string holding cached files of bottleneck values.
    image_dir: Root folder string of the subfolders containing the training
    images.
    jpeg_data_tensor: The layer to feed jpeg image data into.
    bottleneck_tensor: The bottleneck output layer of the CNN graph.

  Returns:
    List of bottleneck arrays, their corresponding ground truths, and the
    relevant filenames.
  """
  class_count = len(image_lists.keys())
  bottlenecks = []
  ground_truths = []
  filenames = []
  if how_many >= 0:
    # Retrieve a random sample of bottlenecks.
    for unused_i in range(how_many):
      label_index = random.randrange(class_count)
      label_name = list(image_lists.keys())[label_index]
      image_index = random.randrange(MAX_NUM_IMAGES_PER_CLASS + 1)
      image_name = get_image_path(image_lists, label_name, image_index,
                                  image_dir, category)
      bottleneck = get_or_create_bottleneck(sess, image_lists, label_name,
                                            image_index, image_dir, category,
                                            bottleneck_dir, jpeg_data_tensor,
                                            bottleneck_tensor)
      ground_truth = np.zeros(class_count, dtype=np.float32)
      ground_truth[label_index] = 1.0
      bottlenecks.append(bottleneck)
      ground_truths.append(ground_truth)
      filenames.append(image_name)
  else:
    # Retrieve all bottlenecks.
    for label_index, label_name in enumerate(image_lists.keys()):
      for image_index, image_name in enumerate(
          image_lists[label_name][category]):
        image_name = get_image_path(image_lists, label_name, image_index,
                                    image_dir, category)
        bottleneck = get_or_create_bottleneck(sess, image_lists, label_name,
                                              image_index, image_dir, category,
                                              bottleneck_dir, jpeg_data_tensor,
                                              bottleneck_tensor)
        ground_truth = np.zeros(class_count, dtype=np.float32)
        ground_truth[label_index] = 1.0
        bottlenecks.append(bottleneck)
        ground_truths.append(ground_truth)
        filenames.append(image_name)
  return bottlenecks, ground_truths, filenames


def get_random_distorted_bottlenecks(
    sess, image_lists, how_many, category, image_dir, input_jpeg_tensor,
    distorted_image, resized_input_tensor, bottleneck_tensor):
  """Retrieves bottleneck values for training images, after distortions.

  If we're training with distortions like crops, scales, or flips, we have to
  recalculate the full model for every image, and so we can't use cached
  bottleneck values. Instead we find random images for the requested category,
  run them through the distortion graph, and then the full graph to get the
  bottleneck results for each.

  Args:
    sess: Current TensorFlow Session.
    image_lists: Dictionary of training images for each label.
    how_many: The integer number of bottleneck values to return.
    category: Name string of which set of images to fetch - training, testing,
    or validation.
    image_dir: Root folder string of the subfolders containing the training
    images.
    input_jpeg_tensor: The input layer we feed the image data to.
    distorted_image: The output node of the distortion graph.
    resized_input_tensor: The input node of the recognition graph.
    bottleneck_tensor: The bottleneck output layer of the CNN graph.

  Returns:
    List of bottleneck arrays and their corresponding ground truths.
  """
  class_count = len(image_lists.keys())
  bottlenecks = []
  ground_truths = []
  for unused_i in range(how_many):
    label_index = random.randrange(class_count)
    label_name = list(image_lists.keys())[label_index]
    image_index = random.randrange(MAX_NUM_IMAGES_PER_CLASS + 1)
    image_path = get_image_path(image_lists, label_name, image_index, image_dir,
                                category)
    if not gfile.Exists(image_path):
      tf.logging.fatal('File does not exist %s', image_path)
    jpeg_data = gfile.FastGFile(image_path, 'rb').read()
    # Note that we materialize the distorted_image_data as a numpy array before
    # sending running inference on the image. This involves 2 memory copies and
    # might be optimized in other implementations.
    distorted_image_data = sess.run(distorted_image,
                                    {input_jpeg_tensor: jpeg_data})
    bottleneck = run_bottleneck_on_image(sess, distorted_image_data,
                                         resized_input_tensor,
                                         bottleneck_tensor)
    ground_truth = np.zeros(class_count, dtype=np.float32)
    ground_truth[label_index] = 1.0
    bottlenecks.append(bottleneck)
    ground_truths.append(ground_truth)
  return bottlenecks, ground_truths


def should_distort_images(flip_left_right, random_crop, random_scale,
                          random_brightness):
  """Whether any distortions are enabled, from the input flags.

  Args:
    flip_left_right: Boolean whether to randomly mirror images horizontally.
    random_crop: Integer percentage setting the total margin used around the
    crop box.
    random_scale: Integer percentage of how much to vary the scale by.
    random_brightness: Integer range to randomly multiply the pixel values by.

  Returns:
    Boolean value indicating whether any distortions should be applied.
  """
  return (flip_left_right or (random_crop != 0) or (random_scale != 0) or
          (random_brightness != 0))


def add_input_distortions(flip_left_right, random_crop, random_scale,
                          random_brightness):
  """Creates the operations to apply the specified distortions.

  During training it can help to improve the results if we run the images
  through simple distortions like crops, scales, and flips. These reflect the
  kind of variations we expect in the real world, and so can help train the
  model to cope with natural data more effectively. Here we take the supplied
  parameters and construct a network of operations to apply them to an image.

  Cropping
  ~~~~~~~~

  Cropping is done by placing a bounding box at a random position in the full
  image. The cropping parameter controls the size of that box relative to the
  input image. If it's zero, then the box is the same size as the input and no
  cropping is performed. If the value is 50%, then the crop box will be half the
  width and height of the input. In a diagram it looks like this:

  <       width         >
  +---------------------+
  |                     |
  |   width - crop%     |
  |    <      >         |
  |    +------+         |
  |    |      |         |
  |    |      |         |
  |    |      |         |
  |    +------+         |
  |                     |
  |                     |
  +---------------------+

  Scaling
  ~~~~~~~

  Scaling is a lot like cropping, except that the bounding box is always
  centered and its size varies randomly within the given range. For example if
  the scale percentage is zero, then the bounding box is the same size as the
  input and no scaling is applied. If it's 50%, then the bounding box will be in
  a random range between half the width and height and full size.

  Args:
    flip_left_right: Boolean whether to randomly mirror images horizontally.
    random_crop: Integer percentage setting the total margin used around the
    crop box.
    random_scale: Integer percentage of how much to vary the scale by.
    random_brightness: Integer range to randomly multiply the pixel values by.
    graph.

  Returns:
    The jpeg input layer and the distorted result tensor.
  """

  jpeg_data = tf.placeholder(tf.string, name='DistortJPGInput')
  decoded_image = tf.image.decode_jpeg(jpeg_data, channels=MODEL_INPUT_DEPTH)
  decoded_image_as_float = tf.cast(decoded_image, dtype=tf.float32)
  decoded_image_4d = tf.expand_dims(decoded_image_as_float, 0)
  margin_scale = 1.0 + (random_crop / 100.0)
  resize_scale = 1.0 + (random_scale / 100.0)
  margin_scale_value = tf.constant(margin_scale)
  resize_scale_value = tf.random_uniform(tensor_shape.scalar(),
                                         minval=1.0,
                                         maxval=resize_scale)
  scale_value = tf.multiply(margin_scale_value, resize_scale_value)
  precrop_width = tf.multiply(scale_value, MODEL_INPUT_WIDTH)
  precrop_height = tf.multiply(scale_value, MODEL_INPUT_HEIGHT)
  precrop_shape = tf.stack([precrop_height, precrop_width])
  precrop_shape_as_int = tf.cast(precrop_shape, dtype=tf.int32)
  precropped_image = tf.image.resize_bilinear(decoded_image_4d,
                                              precrop_shape_as_int)
  precropped_image_3d = tf.squeeze(precropped_image, squeeze_dims=[0])
  cropped_image = tf.random_crop(precropped_image_3d,
                                 [MODEL_INPUT_HEIGHT, MODEL_INPUT_WIDTH,
                                  MODEL_INPUT_DEPTH])
  if flip_left_right:
    flipped_image = tf.image.random_flip_left_right(cropped_image)
  else:
    flipped_image = cropped_image
  brightness_min = 1.0 - (random_brightness / 100.0)
  brightness_max = 1.0 + (random_brightness / 100.0)
  brightness_value = tf.random_uniform(tensor_shape.scalar(),
                                       minval=brightness_min,
                                       maxval=brightness_max)
  brightened_image = tf.multiply(flipped_image, brightness_value)
  distort_result = tf.expand_dims(brightened_image, 0, name='DistortResult')
  return jpeg_data, distort_result


def variable_summaries(var):
  """Attach a lot of summaries to a Tensor (for TensorBoard visualization)."""
  with tf.name_scope('summaries'):
    mean = tf.reduce_mean(var)
    tf.summary.scalar('mean', mean)
    with tf.name_scope('stddev'):
      stddev = tf.sqrt(tf.reduce_mean(tf.square(var - mean)))
    tf.summary.scalar('stddev', stddev)
    tf.summary.scalar('max', tf.reduce_max(var))
    tf.summary.scalar('min', tf.reduce_min(var))
    tf.summary.histogram('histogram', var)


def add_final_training_ops(class_count, final_tensor_name, bottleneck_tensor):
  """Adds a new softmax and fully-connected layer for training.

  We need to retrain the top layer to identify our new classes, so this function
  adds the right operations to the graph, along with some variables to hold the
  weights, and then sets up all the gradients for the backward pass.

  The set up for the softmax and fully-connected layers is based on:
  https://tensorflow.org/versions/master/tutorials/mnist/beginners/index.html

  Args:
    class_count: Integer of how many categories of things we're trying to
    recognize.
    final_tensor_name: Name string for the new final node that produces results.
    bottleneck_tensor: The output of the main CNN graph.

  Returns:
    The tensors for the training and cross entropy results, and tensors for the
    bottleneck input and ground truth input.
  """
  with tf.name_scope('input'):
    bottleneck_input = tf.placeholder_with_default(
        bottleneck_tensor, shape=[None, BOTTLENECK_TENSOR_SIZE],
        name='BottleneckInputPlaceholder')

    ground_truth_input = tf.placeholder(tf.float32,
                                        [None, class_count],
                                        name='GroundTruthInput')

  # Organizing the following ops as `final_training_ops` so they're easier
  # to see in TensorBoard
  layer_name = 'final_training_ops'
  with tf.name_scope(layer_name):
    with tf.name_scope('weights'):
      initial_value = tf.truncated_normal([BOTTLENECK_TENSOR_SIZE, class_count],
                                          stddev=0.001)

      layer_weights = tf.Variable(initial_value, name='final_weights')

      variable_summaries(layer_weights)
    with tf.name_scope('biases'):
      layer_biases = tf.Variable(tf.zeros([class_count]), name='final_biases')
      variable_summaries(layer_biases)
    with tf.name_scope('Wx_plus_b'):
      logits = tf.matmul(bottleneck_input, layer_weights) + layer_biases
      tf.summary.histogram('pre_activations', logits)

  final_tensor = tf.nn.softmax(logits, name=final_tensor_name)
  tf.summary.histogram('activations', final_tensor)

  with tf.name_scope('cross_entropy'):
    cross_entropy = tf.nn.softmax_cross_entropy_with_logits(
        labels=ground_truth_input, logits=logits)
    with tf.name_scope('total'):
      cross_entropy_mean = tf.reduce_mean(cross_entropy)
  tf.summary.scalar('cross_entropy', cross_entropy_mean)

  with tf.name_scope('train'):
    optimizer = tf.train.GradientDescentOptimizer(FLAGS.learning_rate)
    train_step = optimizer.minimize(cross_entropy_mean)

  return (train_step, cross_entropy_mean, bottleneck_input, ground_truth_input,
          final_tensor)


def add_evaluation_step(result_tensor, ground_truth_tensor):
  """Inserts the operations we need to evaluate the accuracy of our results.

  Args:
    result_tensor: The new final node that produces results.
    ground_truth_tensor: The node we feed ground truth data
    into.

  Returns:
    Tuple of (evaluation step, prediction).
  """
  with tf.name_scope('accuracy'):
    with tf.name_scope('correct_prediction'):
      prediction = tf.argmax(result_tensor, 1)
      correct_prediction = tf.equal(
          prediction, tf.argmax(ground_truth_tensor, 1))
    with tf.name_scope('accuracy'):
      evaluation_step = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
  tf.summary.scalar('accuracy', evaluation_step)
  return evaluation_step, prediction


def main(_):
  # Setup the directory we'll write summaries to for TensorBoard
  if tf.gfile.Exists(FLAGS.summaries_dir):
    tf.gfile.DeleteRecursively(FLAGS.summaries_dir)
  tf.gfile.MakeDirs(FLAGS.summaries_dir)

  # Set up the pre-trained graph.
  maybe_download_and_extract()
  graph, bottleneck_tensor, jpeg_data_tensor, resized_image_tensor = (
      create_inception_graph())

  # Look at the folder structure, and create lists of all the images.
  image_lists = create_image_lists(FLAGS.image_dir, FLAGS.testing_percentage,
                                   FLAGS.validation_percentage)
  class_count = len(image_lists.keys())
  if class_count == 0:
    print('No valid folders of images found at ' + FLAGS.image_dir)
    return -1
  if class_count == 1:
    print('Only one valid folder of images found at ' + FLAGS.image_dir +
          ' - multiple classes are needed for classification.')
    return -1

  # See if the command-line flags mean we're applying any distortions.
  do_distort_images = should_distort_images(
      FLAGS.flip_left_right, FLAGS.random_crop, FLAGS.random_scale,
      FLAGS.random_brightness)

  with tf.Session(graph=graph) as sess:

    if do_distort_images:
      # We will be applying distortions, so setup the operations we'll need.
      (distorted_jpeg_data_tensor,
       distorted_image_tensor) = add_input_distortions(
           FLAGS.flip_left_right, FLAGS.random_crop,
           FLAGS.random_scale, FLAGS.random_brightness)
    else:
      # We'll make sure we've calculated the 'bottleneck' image summaries and
      # cached them on disk.
      cache_bottlenecks(sess, image_lists, FLAGS.image_dir,
                        FLAGS.bottleneck_dir, jpeg_data_tensor,
                        bottleneck_tensor)

    # Add the new layer that we'll be training.
    (train_step, cross_entropy, bottleneck_input, ground_truth_input,
     final_tensor) = add_final_training_ops(len(image_lists.keys()),
                                            FLAGS.final_tensor_name,
                                            bottleneck_tensor)

    # Create the operations we need to evaluate the accuracy of our new layer.
    evaluation_step, prediction = add_evaluation_step(
        final_tensor, ground_truth_input)

    # Merge all the summaries and write them out to the summaries_dir
    merged = tf.summary.merge_all()
    train_writer = tf.summary.FileWriter(FLAGS.summaries_dir + '/train',
                                         sess.graph)

    validation_writer = tf.summary.FileWriter(
        FLAGS.summaries_dir + '/validation')

    # Set up all our weights to their initial default values.
    init = tf.global_variables_initializer()
    sess.run(init)

    # Run the training for as many cycles as requested on the command line.
    for i in range(FLAGS.how_many_training_steps):
      # Get a batch of input bottleneck values, either calculated fresh every
      # time with distortions applied, or from the cache stored on disk.
      if do_distort_images:
        (train_bottlenecks,
         train_ground_truth) = get_random_distorted_bottlenecks(
             sess, image_lists, FLAGS.train_batch_size, 'training',
             FLAGS.image_dir, distorted_jpeg_data_tensor,
             distorted_image_tensor, resized_image_tensor, bottleneck_tensor)
      else:
        (train_bottlenecks,
         train_ground_truth, _) = get_random_cached_bottlenecks(
             sess, image_lists, FLAGS.train_batch_size, 'training',
             FLAGS.bottleneck_dir, FLAGS.image_dir, jpeg_data_tensor,
             bottleneck_tensor)
      # Feed the bottlenecks and ground truth into the graph, and run a training
      # step. Capture training summaries for TensorBoard with the `merged` op.

      train_summary, _ = sess.run(
          [merged, train_step],
          feed_dict={bottleneck_input: train_bottlenecks,
                     ground_truth_input: train_ground_truth})
      train_writer.add_summary(train_summary, i)

      # Every so often, print out how well the graph is training.
      is_last_step = (i + 1 == FLAGS.how_many_training_steps)
      if (i % FLAGS.eval_step_interval) == 0 or is_last_step:
        train_accuracy, cross_entropy_value = sess.run(
            [evaluation_step, cross_entropy],
            feed_dict={bottleneck_input: train_bottlenecks,
                       ground_truth_input: train_ground_truth})
        print('%s: Step %d: Train accuracy = %.1f%%' % (datetime.now(), i,
                                                        train_accuracy * 100))
        print('%s: Step %d: Cross entropy = %f' % (datetime.now(), i,
                                                   cross_entropy_value))
        validation_bottlenecks, validation_ground_truth, _ = (
            get_random_cached_bottlenecks(
                sess, image_lists, FLAGS.validation_batch_size, 'validation',
                FLAGS.bottleneck_dir, FLAGS.image_dir, jpeg_data_tensor,
                bottleneck_tensor))
        # Run a validation step and capture training summaries for TensorBoard
        # with the `merged` op.
        validation_summary, validation_accuracy = sess.run(
            [merged, evaluation_step],
            feed_dict={bottleneck_input: validation_bottlenecks,
                       ground_truth_input: validation_ground_truth})
        validation_writer.add_summary(validation_summary, i)
        print('%s: Step %d: Validation accuracy = %.1f%% (N=%d)' %
              (datetime.now(), i, validation_accuracy * 100,
               len(validation_bottlenecks)))

    # We've completed all our training, so run a final test evaluation on
    # some new images we haven't used before.
    test_bottlenecks, test_ground_truth, test_filenames = (
        get_random_cached_bottlenecks(sess, image_lists, FLAGS.test_batch_size,
                                      'testing', FLAGS.bottleneck_dir,
                                      FLAGS.image_dir, jpeg_data_tensor,
                                      bottleneck_tensor))
    test_accuracy, predictions = sess.run(
        [evaluation_step, prediction],
        feed_dict={bottleneck_input: test_bottlenecks,
                   ground_truth_input: test_ground_truth})
    print('Final test accuracy = %.1f%% (N=%d)' % (
        test_accuracy * 100, len(test_bottlenecks)))

    if FLAGS.print_misclassified_test_images:
      print('=== MISCLASSIFIED TEST IMAGES ===')
      for i, test_filename in enumerate(test_filenames):
        if predictions[i] != test_ground_truth[i].argmax():
          print('%70s  %s' % (test_filename,
                              list(image_lists.keys())[predictions[i]]))

    # Write out the trained graph and labels with the weights stored as
    # constants.
    output_graph_def = graph_util.convert_variables_to_constants(
        sess, graph.as_graph_def(), [FLAGS.final_tensor_name])
    with gfile.FastGFile(FLAGS.output_graph, 'wb') as f:
      f.write(output_graph_def.SerializeToString())
    with gfile.FastGFile(FLAGS.output_labels, 'w') as f:
      f.write('\n'.join(image_lists.keys()) + '\n')


if __name__ == '__main__':
  parser = argparse.ArgumentParser()
  parser.add_argument(
      '--image_dir',
      type=str,
      default='',
      help='Path to folders of labeled images.'
  )
  parser.add_argument(
      '--output_graph',
      type=str,
      default='/tmp/output_graph.pb',
      help='Where to save the trained graph.'
  )
  parser.add_argument(
      '--output_labels',
      type=str,
      default='/tmp/output_labels.txt',
      help='Where to save the trained graph\'s labels.'
  )
  parser.add_argument(
      '--summaries_dir',
      type=str,
      default='/tmp/retrain_logs',
      help='Where to save summary logs for TensorBoard.'
  )
  parser.add_argument(
      '--how_many_training_steps',
      type=int,
      default=4000,
      help='How many training steps to run before ending.'
  )
  parser.add_argument(
      '--learning_rate',
      type=float,
      default=0.01,
      help='How large a learning rate to use when training.'
  )
  parser.add_argument(
      '--testing_percentage',
      type=int,
      default=10,
      help='What percentage of images to use as a test set.'
  )
  parser.add_argument(
      '--validation_percentage',
      type=int,
      default=10,
      help='What percentage of images to use as a validation set.'
  )
  parser.add_argument(
      '--eval_step_interval',
      type=int,
      default=10,
      help='How often to evaluate the training results.'
  )
  parser.add_argument(
      '--train_batch_size',
      type=int,
      default=100,
      help='How many images to train on at a time.'
  )
  parser.add_argument(
      '--test_batch_size',
      type=int,
      default=-1,
      help="""\
      How many images to test on. This test set is only used once, to evaluate
      the final accuracy of the model after training completes.
      A value of -1 causes the entire test set to be used, which leads to more
      stable results across runs.\
      """
  )
  parser.add_argument(
      '--validation_batch_size',
      type=int,
      default=100,
      help="""\
      How many images to use in an evaluation batch. This validation set is
      used much more often than the test set, and is an early indicator of how
      accurate the model is during training.
      A value of -1 causes the entire validation set to be used, which leads to
      more stable results across training iterations, but may be slower on large
      training sets.\
      """
  )
  parser.add_argument(
      '--print_misclassified_test_images',
      default=False,
      help="""\
      Whether to print out a list of all misclassified test images.\
      """,
      action='store_true'
  )
  parser.add_argument(
      '--model_dir',
      type=str,
      default='/tmp/imagenet',
      help="""\
      Path to classify_image_graph_def.pb,
      imagenet_synset_to_human_label_map.txt, and
      imagenet_2012_challenge_label_map_proto.pbtxt.\
      """
  )
  parser.add_argument(
      '--bottleneck_dir',
      type=str,
      default='/tmp/bottleneck',
      help='Path to cache bottleneck layer values as files.'
  )
  parser.add_argument(
      '--final_tensor_name',
      type=str,
      default='final_result',
      help="""\
      The name of the output classification layer in the retrained graph.\
      """
  )
  parser.add_argument(
      '--flip_left_right',
      default=False,
      help="""\
      Whether to randomly flip half of the training images horizontally.\
      """,
      action='store_true'
  )
  parser.add_argument(
      '--random_crop',
      type=int,
      default=0,
      help="""\
      A percentage determining how much of a margin to randomly crop off the
      training images.\
      """
  )
  parser.add_argument(
      '--random_scale',
      type=int,
      default=0,
      help="""\
      A percentage determining how much to randomly scale up the size of the
      training images by.\
      """
  )
  parser.add_argument(
      '--random_brightness',
      type=int,
      default=0,
      help="""\
      A percentage determining how much to randomly multiply the training image
      input pixels up or down by.\
      """
  )
  FLAGS, unparsed = parser.parse_known_args()
  tf.app.run(main=main, argv=[sys.argv[0]] + unparsed)

# %% [markdown]
# # sentiment analysis

# %%
# !pip install transformers
# Out:
# Collecting transformers
#   Downloading transformers-4.16.2-py3-none-any.whl (3.5 MB)
#      |████████████████████████████████| 3.5 MB 5.2 MB/s
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.10.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Collecting sacremoses
#   Downloading sacremoses-0.0.47-py2.py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 39.5 MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.4.2)
# Collecting huggingface-hub<1.0,>=0.1.0
#   Downloading huggingface_hub-0.4.0-py3-none-any.whl (67 kB)
#      |████████████████████████████████| 67 kB 4.3 MB/s
# Collecting tokenizers!=0.11.3,>=0.10.1
#   Downloading tokenizers-0.11.4-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.8 MB)
#      |████████████████████████████████| 6.8 MB 32.2 MB/s
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.62.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.19.5)
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 41.6 MB/s
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers) (3.10.0.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.7)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.7.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (7.1.2)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.15.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.1.0)
# Installing collected packages: pyyaml, tokenizers, sacremoses, huggingface-hub, transformers
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed huggingface-hub-0.4.0 pyyaml-6.0 sacremoses-0.0.47 tokenizers-0.11.4 transformers-4.16.2

# %%
from transformers import pipeline

# %%
# Allocate a pipeline for sentiment-analysis
classifier = pipeline('sentiment-analysis')
classifier('We are very happy to introduce pipeline to the transformers repository.')
###[{'label': 'POSITIVE', 'score': 0.9996980428695679}]
# Out:
# No model was supplied, defaulted to distilbert-base-uncased-finetuned-sst-2-english (https://huggingface.co/distilbert-base-uncased-finetuned-sst-2-english)
# Downloading:   0%|          | 0.00/629 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/255M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/226k [00:00<?, ?B/s]
# [{'label': 'POSITIVE', 'score': 0.9996980428695679}]

# %%
classifier('i am going to kill you')
# Out:
# [{'label': 'NEGATIVE', 'score': 0.9948242902755737}]

# %% [markdown]
# # plastics : 2

# %%
# !pip install scipy==1.1.0
# Out:
# Collecting scipy==1.1.0
#   Downloading scipy-1.1.0-cp37-cp37m-manylinux1_x86_64.whl (31.2 MB)
#      |████████████████████████████████| 31.2 MB 21.6 MB/s
# Requirement already satisfied: numpy>=1.8.2 in /usr/local/lib/python3.7/dist-packages (from scipy==1.1.0) (1.19.5)
# Installing collected packages: scipy
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.4.1
#     Uninstalling scipy-1.4.1:
#       Successfully uninstalled scipy-1.4.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pymc3 3.11.4 requires scipy>=1.2.0, but you have scipy 1.1.0 which is incompatible.
# plotnine 0.6.0 requires scipy>=1.2.0, but you have scipy 1.1.0 which is incompatible.
# jax 0.2.25 requires scipy>=1.2.1, but you have scipy 1.1.0 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# Successfully installed scipy-1.1.0

# %%
# !python /content/drive/MyDrive/trashnet-data/resize.py
# Out:
# /content/drive/MyDrive/trashnet-data/resize.py:21: DeprecationWarning:     `imread` is deprecated!
#     `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
#     Use ``imageio.imread`` instead.
#   pic = misc.imread(os.path.join(subdir, file))
# /content/drive/MyDrive/trashnet-data/resize.py:7: DeprecationWarning:     `imresize` is deprecated!
#     `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
#     Use ``skimage.transform.resize`` instead.
#   return misc.imresize(image, (dim1, dim2))
# /content/drive/MyDrive/trashnet-data/resize.py:28: DeprecationWarning:     `imsave` is deprecated!
#     `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
#     Use ``imageio.imwrite`` instead.
#   misc.imsave(os.path.join(destPath, file), picResized)

# %%
# !unzip /content/drive/MyDrive/trashnet-data/dataset-original.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard132.jpg
#   inflating: dataset-original/cardboard/cardboard133.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard133.jpg
#   inflating: dataset-original/cardboard/cardboard134.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard134.jpg
#   inflating: dataset-original/cardboard/cardboard135.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard135.jpg
#   inflating: dataset-original/cardboard/cardboard136.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard136.jpg
#   inflating: dataset-original/cardboard/cardboard137.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard137.jpg
#   inflating: dataset-original/cardboard/cardboard138.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard138.jpg
#   inflating: dataset-original/cardboard/cardboard139.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard139.jpg
#   inflating: dataset-original/cardboard/cardboard14.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard14.jpg
#   inflating: dataset-original/cardboard/cardboard140.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard140.jpg
#   inflating: dataset-original/cardboard/cardboard141.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard141.jpg
#   inflating: dataset-original/cardboard/cardboard142.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard142.jpg
#   inflating: dataset-original/cardboard/cardboard143.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard143.jpg
#   inflating: dataset-original/cardboard/cardboard144.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard144.jpg
#   inflating: dataset-original/cardboard/cardboard145.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard145.jpg
#   inflating: dataset-original/cardboard/cardboard146.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard146.jpg
#   inflating: dataset-original/cardboard/cardboard147.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard147.jpg
#   inflating: dataset-original/cardboard/cardboard148.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard148.jpg
#   inflating: dataset-original/cardboard/cardboard149.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard149.jpg
#   inflating: dataset-original/cardboard/cardboard15.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard15.jpg
#   inflating: dataset-original/cardboard/cardboard150.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard150.jpg
#   inflating: dataset-original/cardboard/cardboard151.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard151.jpg
#   inflating: dataset-original/cardboard/cardboard152.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard152.jpg
#   inflating: dataset-original/cardboard/cardboard153.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard153.jpg
#   inflating: dataset-original/cardboard/cardboard154.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard154.jpg
#   inflating: dataset-original/cardboard/cardboard155.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard155.jpg
#   inflating: dataset-original/cardboard/cardboard156.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard156.jpg
#   inflating: dataset-original/cardboard/cardboard157.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard157.jpg
#   inflating: dataset-original/cardboard/cardboard158.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard158.jpg
#   inflating: dataset-original/cardboard/cardboard159.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard159.jpg
#   inflating: dataset-original/cardboard/cardboard16.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard16.jpg
#   inflating: dataset-original/cardboard/cardboard160.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard160.jpg
#   inflating: dataset-original/cardboard/cardboard161.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard161.jpg
#   inflating: dataset-original/cardboard/cardboard162.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard162.jpg
#   inflating: dataset-original/cardboard/cardboard163.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard163.jpg
#   inflating: dataset-original/cardboard/cardboard164.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard164.jpg
#   inflating: dataset-original/cardboard/cardboard165.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard165.jpg
#   inflating: dataset-original/cardboard/cardboard166.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard166.jpg
#   inflating: dataset-original/cardboard/cardboard167.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard167.jpg
#   inflating: dataset-original/cardboard/cardboard168.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard168.jpg
#   inflating: dataset-original/cardboard/cardboard169.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard169.jpg
#   inflating: dataset-original/cardboard/cardboard17.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard17.jpg
#   inflating: dataset-original/cardboard/cardboard170.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard170.jpg
#   inflating: dataset-original/cardboard/cardboard171.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard171.jpg
#   inflating: dataset-original/cardboard/cardboard172.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard172.jpg
#   inflating: dataset-original/cardboard/cardboard173.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard173.jpg
#   inflating: dataset-original/cardboard/cardboard174.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard174.jpg
#   inflating: dataset-original/cardboard/cardboard175.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard175.jpg
#   inflating: dataset-original/cardboard/cardboard176.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard176.jpg
#   inflating: dataset-original/cardboard/cardboard177.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard177.jpg
#   inflating: dataset-original/cardboard/cardboard178.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard178.jpg
#   inflating: dataset-original/cardboard/cardboard179.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard179.jpg
#   inflating: dataset-original/cardboard/cardboard18.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard18.jpg
#   inflating: dataset-original/cardboard/cardboard180.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard180.jpg
#   inflating: dataset-original/cardboard/cardboard181.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard181.jpg
#   inflating: dataset-original/cardboard/cardboard182.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard182.jpg
#   inflating: dataset-original/cardboard/cardboard183.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard183.jpg
#   inflating: dataset-original/cardboard/cardboard184.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard184.jpg
#   inflating: dataset-original/cardboard/cardboard185.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard185.jpg
#   inflating: dataset-original/cardboard/cardboard186.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard186.jpg
#   inflating: dataset-original/cardboard/cardboard187.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard187.jpg
#   inflating: dataset-original/cardboard/cardboard188.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard188.jpg
#   inflating: dataset-original/cardboard/cardboard189.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard189.jpg
#   inflating: dataset-original/cardboard/cardboard19.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard19.jpg
#   inflating: dataset-original/cardboard/cardboard190.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard190.jpg
#   inflating: dataset-original/cardboard/cardboard191.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard191.jpg
#   inflating: dataset-original/cardboard/cardboard192.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard192.jpg
#   inflating: dataset-original/cardboard/cardboard193.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard193.jpg
#   inflating: dataset-original/cardboard/cardboard194.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard194.jpg
#   inflating: dataset-original/cardboard/cardboard195.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard195.jpg
#   inflating: dataset-original/cardboard/cardboard196.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard196.jpg
#   inflating: dataset-original/cardboard/cardboard197.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard197.jpg
#   inflating: dataset-original/cardboard/cardboard198.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard198.jpg
#   inflating: dataset-original/cardboard/cardboard199.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard199.jpg
#   inflating: dataset-original/cardboard/cardboard2.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard2.jpg
#   inflating: dataset-original/cardboard/cardboard20.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard20.jpg
#   inflating: dataset-original/cardboard/cardboard200.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard200.jpg
#   inflating: dataset-original/cardboard/cardboard201.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard201.jpg
#   inflating: dataset-original/cardboard/cardboard202.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard202.jpg
#   inflating: dataset-original/cardboard/cardboard203.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard203.jpg
#   inflating: dataset-original/cardboard/cardboard204.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard204.jpg
#   inflating: dataset-original/cardboard/cardboard205.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard205.jpg
#   inflating: dataset-original/cardboard/cardboard206.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard206.jpg
#   inflating: dataset-original/cardboard/cardboard207.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard207.jpg
#   inflating: dataset-original/cardboard/cardboard208.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard208.jpg
#   inflating: dataset-original/cardboard/cardboard209.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard209.jpg
#   inflating: dataset-original/cardboard/cardboard21.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard21.jpg
#   inflating: dataset-original/cardboard/cardboard210.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard210.jpg
#   inflating: dataset-original/cardboard/cardboard211.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard211.jpg
#   inflating: dataset-original/cardboard/cardboard212.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard212.jpg
#   inflating: dataset-original/cardboard/cardboard213.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard213.jpg
#   inflating: dataset-original/cardboard/cardboard214.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard214.jpg
#   inflating: dataset-original/cardboard/cardboard215.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard215.jpg
#   inflating: dataset-original/cardboard/cardboard216.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard216.jpg
#   inflating: dataset-original/cardboard/cardboard217.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard217.jpg
#   inflating: dataset-original/cardboard/cardboard218.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard218.jpg
#   inflating: dataset-original/cardboard/cardboard219.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard219.jpg
#   inflating: dataset-original/cardboard/cardboard22.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard22.jpg
#   inflating: dataset-original/cardboard/cardboard220.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard220.jpg
#   inflating: dataset-original/cardboard/cardboard221.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard221.jpg
#   inflating: dataset-original/cardboard/cardboard222.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard222.jpg
#   inflating: dataset-original/cardboard/cardboard223.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard223.jpg
#   inflating: dataset-original/cardboard/cardboard224.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard224.jpg
#   inflating: dataset-original/cardboard/cardboard225.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard225.jpg
#   inflating: dataset-original/cardboard/cardboard226.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard226.jpg
#   inflating: dataset-original/cardboard/cardboard227.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard227.jpg
#   inflating: dataset-original/cardboard/cardboard228.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard228.jpg
#   inflating: dataset-original/cardboard/cardboard229.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard229.jpg
#   inflating: dataset-original/cardboard/cardboard23.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard23.jpg
#   inflating: dataset-original/cardboard/cardboard230.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard230.jpg
#   inflating: dataset-original/cardboard/cardboard231.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard231.jpg
#   inflating: dataset-original/cardboard/cardboard232.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard232.jpg
#   inflating: dataset-original/cardboard/cardboard233.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard233.jpg
#   inflating: dataset-original/cardboard/cardboard234.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard234.jpg
#   inflating: dataset-original/cardboard/cardboard235.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard235.jpg
#   inflating: dataset-original/cardboard/cardboard236.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard236.jpg
#   inflating: dataset-original/cardboard/cardboard237.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard237.jpg
#   inflating: dataset-original/cardboard/cardboard238.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard238.jpg
#   inflating: dataset-original/cardboard/cardboard239.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard239.jpg
#   inflating: dataset-original/cardboard/cardboard24.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard24.jpg
#   inflating: dataset-original/cardboard/cardboard240.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard240.jpg
#   inflating: dataset-original/cardboard/cardboard241.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard241.jpg
#   inflating: dataset-original/cardboard/cardboard242.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard242.jpg
#   inflating: dataset-original/cardboard/cardboard243.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard243.jpg
#   inflating: dataset-original/cardboard/cardboard244.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard244.jpg
#   inflating: dataset-original/cardboard/cardboard245.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard245.jpg
#   inflating: dataset-original/cardboard/cardboard246.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard246.jpg
#   inflating: dataset-original/cardboard/cardboard247.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard247.jpg
#   inflating: dataset-original/cardboard/cardboard248.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard248.jpg
#   inflating: dataset-original/cardboard/cardboard249.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard249.jpg
#   inflating: dataset-original/cardboard/cardboard25.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard25.jpg
#   inflating: dataset-original/cardboard/cardboard250.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard250.jpg
#   inflating: dataset-original/cardboard/cardboard251.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard251.jpg
#   inflating: dataset-original/cardboard/cardboard252.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard252.jpg
#   inflating: dataset-original/cardboard/cardboard253.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard253.jpg
#   inflating: dataset-original/cardboard/cardboard254.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard254.jpg
#   inflating: dataset-original/cardboard/cardboard255.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard255.jpg
#   inflating: dataset-original/cardboard/cardboard256.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard256.jpg
#   inflating: dataset-original/cardboard/cardboard257.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard257.jpg
#   inflating: dataset-original/cardboard/cardboard258.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard258.jpg
#   inflating: dataset-original/cardboard/cardboard259.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard259.jpg
#   inflating: dataset-original/cardboard/cardboard26.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard26.jpg
#   inflating: dataset-original/cardboard/cardboard260.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard260.jpg
#   inflating: dataset-original/cardboard/cardboard261.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard261.jpg
#   inflating: dataset-original/cardboard/cardboard262.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard262.jpg
#   inflating: dataset-original/cardboard/cardboard263.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard263.jpg
#   inflating: dataset-original/cardboard/cardboard264.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard264.jpg
#   inflating: dataset-original/cardboard/cardboard265.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard265.jpg
#   inflating: dataset-original/cardboard/cardboard266.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard266.jpg
#   inflating: dataset-original/cardboard/cardboard267.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard267.jpg
#   inflating: dataset-original/cardboard/cardboard268.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard268.jpg
#   inflating: dataset-original/cardboard/cardboard269.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard269.jpg
#   inflating: dataset-original/cardboard/cardboard27.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard27.jpg
#   inflating: dataset-original/cardboard/cardboard270.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard270.jpg
#   inflating: dataset-original/cardboard/cardboard271.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard271.jpg
#   inflating: dataset-original/cardboard/cardboard272.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard272.jpg
#   inflating: dataset-original/cardboard/cardboard273.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard273.jpg
#   inflating: dataset-original/cardboard/cardboard274.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard274.jpg
#   inflating: dataset-original/cardboard/cardboard275.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard275.jpg
#   inflating: dataset-original/cardboard/cardboard276.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard276.jpg
#   inflating: dataset-original/cardboard/cardboard277.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard277.jpg
#   inflating: dataset-original/cardboard/cardboard278.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard278.jpg
#   inflating: dataset-original/cardboard/cardboard279.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard279.jpg
#   inflating: dataset-original/cardboard/cardboard28.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard28.jpg
#   inflating: dataset-original/cardboard/cardboard280.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard280.jpg
#   inflating: dataset-original/cardboard/cardboard281.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard281.jpg
#   inflating: dataset-original/cardboard/cardboard282.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard282.jpg
#   inflating: dataset-original/cardboard/cardboard283.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard283.jpg
#   inflating: dataset-original/cardboard/cardboard284.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard284.jpg
#   inflating: dataset-original/cardboard/cardboard285.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard285.jpg
#   inflating: dataset-original/cardboard/cardboard286.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard286.jpg
#   inflating: dataset-original/cardboard/cardboard287.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard287.jpg
#   inflating: dataset-original/cardboard/cardboard288.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard288.jpg
#   inflating: dataset-original/cardboard/cardboard289.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard289.jpg
#   inflating: dataset-original/cardboard/cardboard29.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard29.jpg
#   inflating: dataset-original/cardboard/cardboard290.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard290.jpg
#   inflating: dataset-original/cardboard/cardboard291.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard291.jpg
#   inflating: dataset-original/cardboard/cardboard292.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard292.jpg
#   inflating: dataset-original/cardboard/cardboard293.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard293.jpg
#   inflating: dataset-original/cardboard/cardboard294.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard294.jpg
#   inflating: dataset-original/cardboard/cardboard295.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard295.jpg
#   inflating: dataset-original/cardboard/cardboard296.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard296.jpg
#   inflating: dataset-original/cardboard/cardboard297.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard297.jpg
#   inflating: dataset-original/cardboard/cardboard298.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard298.jpg
#   inflating: dataset-original/cardboard/cardboard299.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard299.jpg
#   inflating: dataset-original/cardboard/cardboard3.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard3.jpg
#   inflating: dataset-original/cardboard/cardboard30.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard30.jpg
#   inflating: dataset-original/cardboard/cardboard300.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard300.jpg
#   inflating: dataset-original/cardboard/cardboard301.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard301.jpg
#   inflating: dataset-original/cardboard/cardboard302.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard302.jpg
#   inflating: dataset-original/cardboard/cardboard303.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard303.jpg
#   inflating: dataset-original/cardboard/cardboard304.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard304.jpg
#   inflating: dataset-original/cardboard/cardboard305.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard305.jpg
#   inflating: dataset-original/cardboard/cardboard306.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard306.jpg
#   inflating: dataset-original/cardboard/cardboard307.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard307.jpg
#   inflating: dataset-original/cardboard/cardboard308.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard308.jpg
#   inflating: dataset-original/cardboard/cardboard309.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard309.jpg
#   inflating: dataset-original/cardboard/cardboard31.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard31.jpg
#   inflating: dataset-original/cardboard/cardboard310.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard310.jpg
#   inflating: dataset-original/cardboard/cardboard311.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard311.jpg
#   inflating: dataset-original/cardboard/cardboard312.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard312.jpg
#   inflating: dataset-original/cardboard/cardboard313.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard313.jpg
#   inflating: dataset-original/cardboard/cardboard314.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard314.jpg
#   inflating: dataset-original/cardboard/cardboard315.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard315.jpg
#   inflating: dataset-original/cardboard/cardboard316.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard316.jpg
#   inflating: dataset-original/cardboard/cardboard317.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard317.jpg
#   inflating: dataset-original/cardboard/cardboard318.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard318.jpg
#   inflating: dataset-original/cardboard/cardboard319.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard319.jpg
#   inflating: dataset-original/cardboard/cardboard32.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard32.jpg
#   inflating: dataset-original/cardboard/cardboard320.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard320.jpg
#   inflating: dataset-original/cardboard/cardboard321.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard321.jpg
#   inflating: dataset-original/cardboard/cardboard322.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard322.jpg
#   inflating: dataset-original/cardboard/cardboard323.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard323.jpg
#   inflating: dataset-original/cardboard/cardboard324.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard324.jpg
#   inflating: dataset-original/cardboard/cardboard325.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard325.jpg
#   inflating: dataset-original/cardboard/cardboard326.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard326.jpg
#   inflating: dataset-original/cardboard/cardboard327.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard327.jpg
#   inflating: dataset-original/cardboard/cardboard328.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard328.jpg
#   inflating: dataset-original/cardboard/cardboard329.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard329.jpg
#   inflating: dataset-original/cardboard/cardboard33.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard33.jpg
#   inflating: dataset-original/cardboard/cardboard330.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard330.jpg
#   inflating: dataset-original/cardboard/cardboard331.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard331.jpg
#   inflating: dataset-original/cardboard/cardboard332.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard332.jpg
#   inflating: dataset-original/cardboard/cardboard333.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard333.jpg
#   inflating: dataset-original/cardboard/cardboard334.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard334.jpg
#   inflating: dataset-original/cardboard/cardboard335.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard335.jpg
#   inflating: dataset-original/cardboard/cardboard336.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard336.jpg
#   inflating: dataset-original/cardboard/cardboard337.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard337.jpg
#   inflating: dataset-original/cardboard/cardboard338.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard338.jpg
#   inflating: dataset-original/cardboard/cardboard339.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard339.jpg
#   inflating: dataset-original/cardboard/cardboard34.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard34.jpg
#   inflating: dataset-original/cardboard/cardboard340.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard340.jpg
#   inflating: dataset-original/cardboard/cardboard341.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard341.jpg
#   inflating: dataset-original/cardboard/cardboard342.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard342.jpg
#   inflating: dataset-original/cardboard/cardboard343.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard343.jpg
#   inflating: dataset-original/cardboard/cardboard344.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard344.jpg
#   inflating: dataset-original/cardboard/cardboard345.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard345.jpg
#   inflating: dataset-original/cardboard/cardboard346.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard346.jpg
#   inflating: dataset-original/cardboard/cardboard347.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard347.jpg
#   inflating: dataset-original/cardboard/cardboard348.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard348.jpg
#   inflating: dataset-original/cardboard/cardboard349.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard349.jpg
#   inflating: dataset-original/cardboard/cardboard35.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard35.jpg
#   inflating: dataset-original/cardboard/cardboard350.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard350.jpg
#   inflating: dataset-original/cardboard/cardboard351.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard351.jpg
#   inflating: dataset-original/cardboard/cardboard352.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard352.jpg
#   inflating: dataset-original/cardboard/cardboard353.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard353.jpg
#   inflating: dataset-original/cardboard/cardboard354.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard354.jpg
#   inflating: dataset-original/cardboard/cardboard355.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard355.jpg
#   inflating: dataset-original/cardboard/cardboard356.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard356.jpg
#   inflating: dataset-original/cardboard/cardboard357.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard357.jpg
#   inflating: dataset-original/cardboard/cardboard358.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard358.jpg
#   inflating: dataset-original/cardboard/cardboard359.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard359.jpg
#   inflating: dataset-original/cardboard/cardboard36.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard36.jpg
#   inflating: dataset-original/cardboard/cardboard360.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard360.jpg
#   inflating: dataset-original/cardboard/cardboard361.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard361.jpg
#   inflating: dataset-original/cardboard/cardboard362.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard362.jpg
#   inflating: dataset-original/cardboard/cardboard363.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard363.jpg
#   inflating: dataset-original/cardboard/cardboard364.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard364.jpg
#   inflating: dataset-original/cardboard/cardboard365.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard365.jpg
#   inflating: dataset-original/cardboard/cardboard366.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard366.jpg
#   inflating: dataset-original/cardboard/cardboard367.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard367.jpg
#   inflating: dataset-original/cardboard/cardboard368.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard368.jpg
#   inflating: dataset-original/cardboard/cardboard369.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard369.jpg
#   inflating: dataset-original/cardboard/cardboard37.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard37.jpg
#   inflating: dataset-original/cardboard/cardboard370.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard370.jpg
#   inflating: dataset-original/cardboard/cardboard371.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard371.jpg
#   inflating: dataset-original/cardboard/cardboard372.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard372.jpg
#   inflating: dataset-original/cardboard/cardboard373.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard373.jpg
#   inflating: dataset-original/cardboard/cardboard374.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard374.jpg
#   inflating: dataset-original/cardboard/cardboard375.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard375.jpg
#   inflating: dataset-original/cardboard/cardboard376.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard376.jpg
#   inflating: dataset-original/cardboard/cardboard377.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard377.jpg
#   inflating: dataset-original/cardboard/cardboard378.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard378.jpg
#   inflating: dataset-original/cardboard/cardboard379.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard379.jpg
#   inflating: dataset-original/cardboard/cardboard38.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard38.jpg
#   inflating: dataset-original/cardboard/cardboard380.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard380.jpg
#   inflating: dataset-original/cardboard/cardboard381.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard381.jpg
#   inflating: dataset-original/cardboard/cardboard382.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard382.jpg
#   inflating: dataset-original/cardboard/cardboard383.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard383.jpg
#   inflating: dataset-original/cardboard/cardboard384.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard384.jpg
#   inflating: dataset-original/cardboard/cardboard385.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard385.jpg
#   inflating: dataset-original/cardboard/cardboard386.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard386.jpg
#   inflating: dataset-original/cardboard/cardboard387.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard387.jpg
#   inflating: dataset-original/cardboard/cardboard388.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard388.jpg
#   inflating: dataset-original/cardboard/cardboard389.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard389.jpg
#   inflating: dataset-original/cardboard/cardboard39.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard39.jpg
#   inflating: dataset-original/cardboard/cardboard390.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard390.jpg
#   inflating: dataset-original/cardboard/cardboard391.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard391.jpg
#   inflating: dataset-original/cardboard/cardboard392.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard392.jpg
#   inflating: dataset-original/cardboard/cardboard393.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard393.jpg
#   inflating: dataset-original/cardboard/cardboard394.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard394.jpg
#   inflating: dataset-original/cardboard/cardboard395.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard395.jpg
#   inflating: dataset-original/cardboard/cardboard396.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard396.jpg
#   inflating: dataset-original/cardboard/cardboard397.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard397.jpg
#   inflating: dataset-original/cardboard/cardboard398.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard398.jpg
#   inflating: dataset-original/cardboard/cardboard399.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard399.jpg
#   inflating: dataset-original/cardboard/cardboard4.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard4.jpg
#   inflating: dataset-original/cardboard/cardboard40.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard40.jpg
#   inflating: dataset-original/cardboard/cardboard400.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard400.jpg
#   inflating: dataset-original/cardboard/cardboard401.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard401.jpg
#   inflating: dataset-original/cardboard/cardboard402.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard402.jpg
#   inflating: dataset-original/cardboard/cardboard403.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard403.jpg
#   inflating: dataset-original/cardboard/cardboard41.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard41.jpg
#   inflating: dataset-original/cardboard/cardboard42.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard42.jpg
#   inflating: dataset-original/cardboard/cardboard43.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard43.jpg
#   inflating: dataset-original/cardboard/cardboard44.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard44.jpg
#   inflating: dataset-original/cardboard/cardboard45.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard45.jpg
#   inflating: dataset-original/cardboard/cardboard46.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard46.jpg
#   inflating: dataset-original/cardboard/cardboard47.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard47.jpg
#   inflating: dataset-original/cardboard/cardboard48.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard48.jpg
#   inflating: dataset-original/cardboard/cardboard49.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard49.jpg
#   inflating: dataset-original/cardboard/cardboard5.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard5.jpg
#   inflating: dataset-original/cardboard/cardboard50.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard50.jpg
#   inflating: dataset-original/cardboard/cardboard51.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard51.jpg
#   inflating: dataset-original/cardboard/cardboard52.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard52.jpg
#   inflating: dataset-original/cardboard/cardboard53.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard53.jpg
#   inflating: dataset-original/cardboard/cardboard54.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard54.jpg
#   inflating: dataset-original/cardboard/cardboard55.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard55.jpg
#   inflating: dataset-original/cardboard/cardboard56.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard56.jpg
#   inflating: dataset-original/cardboard/cardboard57.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard57.jpg
#   inflating: dataset-original/cardboard/cardboard58.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard58.jpg
#   inflating: dataset-original/cardboard/cardboard59.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard59.jpg
#   inflating: dataset-original/cardboard/cardboard6.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard6.jpg
#   inflating: dataset-original/cardboard/cardboard60.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard60.jpg
#   inflating: dataset-original/cardboard/cardboard61.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard61.jpg
#   inflating: dataset-original/cardboard/cardboard62.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard62.jpg
#   inflating: dataset-original/cardboard/cardboard63.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard63.jpg
#   inflating: dataset-original/cardboard/cardboard64.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard64.jpg
#   inflating: dataset-original/cardboard/cardboard65.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard65.jpg
#   inflating: dataset-original/cardboard/cardboard66.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard66.jpg
#   inflating: dataset-original/cardboard/cardboard67.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard67.jpg
#   inflating: dataset-original/cardboard/cardboard68.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard68.jpg
#   inflating: dataset-original/cardboard/cardboard69.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard69.jpg
#   inflating: dataset-original/cardboard/cardboard7.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard7.jpg
#   inflating: dataset-original/cardboard/cardboard70.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard70.jpg
#   inflating: dataset-original/cardboard/cardboard71.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard71.jpg
#   inflating: dataset-original/cardboard/cardboard72.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard72.jpg
#   inflating: dataset-original/cardboard/cardboard73.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard73.jpg
#   inflating: dataset-original/cardboard/cardboard74.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard74.jpg
#   inflating: dataset-original/cardboard/cardboard75.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard75.jpg
#   inflating: dataset-original/cardboard/cardboard76.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard76.jpg
#   inflating: dataset-original/cardboard/cardboard77.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard77.jpg
#   inflating: dataset-original/cardboard/cardboard78.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard78.jpg
#   inflating: dataset-original/cardboard/cardboard79.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard79.jpg
#   inflating: dataset-original/cardboard/cardboard8.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard8.jpg
#   inflating: dataset-original/cardboard/cardboard80.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard80.jpg
#   inflating: dataset-original/cardboard/cardboard81.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard81.jpg
#   inflating: dataset-original/cardboard/cardboard82.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard82.jpg
#   inflating: dataset-original/cardboard/cardboard83.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard83.jpg
#   inflating: dataset-original/cardboard/cardboard84.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard84.jpg
#   inflating: dataset-original/cardboard/cardboard85.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard85.jpg
#   inflating: dataset-original/cardboard/cardboard86.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard86.jpg
#   inflating: dataset-original/cardboard/cardboard87.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard87.jpg
#   inflating: dataset-original/cardboard/cardboard88.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard88.jpg
#   inflating: dataset-original/cardboard/cardboard89.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard89.jpg
#   inflating: dataset-original/cardboard/cardboard9.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard9.jpg
#   inflating: dataset-original/cardboard/cardboard90.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard90.jpg
#   inflating: dataset-original/cardboard/cardboard91.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard91.jpg
#   inflating: dataset-original/cardboard/cardboard92.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard92.jpg
#   inflating: dataset-original/cardboard/cardboard93.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard93.jpg
#   inflating: dataset-original/cardboard/cardboard94.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard94.jpg
#   inflating: dataset-original/cardboard/cardboard95.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard95.jpg
#   inflating: dataset-original/cardboard/cardboard96.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard96.jpg
#   inflating: dataset-original/cardboard/cardboard97.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard97.jpg
#   inflating: dataset-original/cardboard/cardboard98.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard98.jpg
#   inflating: dataset-original/cardboard/cardboard99.jpg
#   inflating: __MACOSX/dataset-original/cardboard/._cardboard99.jpg
#   inflating: __MACOSX/dataset-original/._cardboard
#    creating: dataset-original/glass/
#   inflating: dataset-original/glass/.DS_Store
#   inflating: dataset-original/glass/glass1.jpg
#    creating: __MACOSX/dataset-original/glass/
#   inflating: __MACOSX/dataset-original/glass/._glass1.jpg
#   inflating: dataset-original/glass/glass10.jpg
#   inflating: __MACOSX/dataset-original/glass/._glass10.jpg
#   inflating: dataset-original/glass/glass100.jpg
#   inflating: __MACOSX/dataset-original/glass/._glass100.jpg
#   inflating: dataset-original/glass/glass101.jpg
#   inflating: __MACOSX/dataset-original/glass/._glass101.jpg
#   inflating: dataset-original/glass/glass102.jpg
#   inflating: __MACOSX/dataset-original/glass/._glass102.jpg
#   inflating: dataset-original/glass/glass103.jpg
#   inflating: __MACOSX/dataset-original/glass/._glass103.jpg
#   inflating: dataset-original/glass/glass104.jpg
#   inflating: __MACOSX/dataset-original/glass/._glass104.jpg
# ...
#   inflating: dataset-original/plastic/plastic96.jpg
#   inflating: __MACOSX/dataset-original/plastic/._plastic96.jpg
#   inflating: dataset-original/plastic/plastic97.jpg
#   inflating: __MACOSX/dataset-original/plastic/._plastic97.jpg
#   inflating: dataset-original/plastic/plastic98.jpg
#   inflating: __MACOSX/dataset-original/plastic/._plastic98.jpg
#   inflating: dataset-original/plastic/plastic99.jpg
#   inflating: __MACOSX/dataset-original/plastic/._plastic99.jpg
#   inflating: __MACOSX/dataset-original/._plastic
#    creating: dataset-original/trash/
#   inflating: dataset-original/trash/trash1.jpg
#    creating: __MACOSX/dataset-original/trash/
#   inflating: __MACOSX/dataset-original/trash/._trash1.jpg
#   inflating: dataset-original/trash/trash10.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash10.jpg
#   inflating: dataset-original/trash/trash100.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash100.jpg
#   inflating: dataset-original/trash/trash101.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash101.jpg
#   inflating: dataset-original/trash/trash102.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash102.jpg
#   inflating: dataset-original/trash/trash103.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash103.jpg
#   inflating: dataset-original/trash/trash104.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash104.jpg
#   inflating: dataset-original/trash/trash105.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash105.jpg
#   inflating: dataset-original/trash/trash106.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash106.jpg
#   inflating: dataset-original/trash/trash107.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash107.jpg
#   inflating: dataset-original/trash/trash108.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash108.jpg
#   inflating: dataset-original/trash/trash109.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash109.jpg
#   inflating: dataset-original/trash/trash11.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash11.jpg
#   inflating: dataset-original/trash/trash110.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash110.jpg
#   inflating: dataset-original/trash/trash111.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash111.jpg
#   inflating: dataset-original/trash/trash112.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash112.jpg
#   inflating: dataset-original/trash/trash113.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash113.jpg
#   inflating: dataset-original/trash/trash114.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash114.jpg
#   inflating: dataset-original/trash/trash115.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash115.jpg
#   inflating: dataset-original/trash/trash116.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash116.jpg
#   inflating: dataset-original/trash/trash117.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash117.jpg
#   inflating: dataset-original/trash/trash118.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash118.jpg
#   inflating: dataset-original/trash/trash119.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash119.jpg
#   inflating: dataset-original/trash/trash12.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash12.jpg
#   inflating: dataset-original/trash/trash120.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash120.jpg
#   inflating: dataset-original/trash/trash121.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash121.jpg
#   inflating: dataset-original/trash/trash122.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash122.jpg
#   inflating: dataset-original/trash/trash123.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash123.jpg
#   inflating: dataset-original/trash/trash124.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash124.jpg
#   inflating: dataset-original/trash/trash125.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash125.jpg
#   inflating: dataset-original/trash/trash126.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash126.jpg
#   inflating: dataset-original/trash/trash127.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash127.jpg
#   inflating: dataset-original/trash/trash128.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash128.jpg
#   inflating: dataset-original/trash/trash129.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash129.jpg
#   inflating: dataset-original/trash/trash13.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash13.jpg
#   inflating: dataset-original/trash/trash130.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash130.jpg
#   inflating: dataset-original/trash/trash131.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash131.jpg
#   inflating: dataset-original/trash/trash132.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash132.jpg
#   inflating: dataset-original/trash/trash133.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash133.jpg
#   inflating: dataset-original/trash/trash134.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash134.jpg
#   inflating: dataset-original/trash/trash135.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash135.jpg
#   inflating: dataset-original/trash/trash136.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash136.jpg
#   inflating: dataset-original/trash/trash137.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash137.jpg
#   inflating: dataset-original/trash/trash14.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash14.jpg
#   inflating: dataset-original/trash/trash15.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash15.jpg
#   inflating: dataset-original/trash/trash16.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash16.jpg
#   inflating: dataset-original/trash/trash17.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash17.jpg
#   inflating: dataset-original/trash/trash18.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash18.jpg
#   inflating: dataset-original/trash/trash19.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash19.jpg
#   inflating: dataset-original/trash/trash2.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash2.jpg
#   inflating: dataset-original/trash/trash20.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash20.jpg
#   inflating: dataset-original/trash/trash21.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash21.jpg
#   inflating: dataset-original/trash/trash22.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash22.jpg
#   inflating: dataset-original/trash/trash23.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash23.jpg
#   inflating: dataset-original/trash/trash24.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash24.jpg
#   inflating: dataset-original/trash/trash25.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash25.jpg
#   inflating: dataset-original/trash/trash26.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash26.jpg
#   inflating: dataset-original/trash/trash27.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash27.jpg
#   inflating: dataset-original/trash/trash28.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash28.jpg
#   inflating: dataset-original/trash/trash29.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash29.jpg
#   inflating: dataset-original/trash/trash3.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash3.jpg
#   inflating: dataset-original/trash/trash30.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash30.jpg
#   inflating: dataset-original/trash/trash31.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash31.jpg
#   inflating: dataset-original/trash/trash32.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash32.jpg
#   inflating: dataset-original/trash/trash33.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash33.jpg
#   inflating: dataset-original/trash/trash34.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash34.jpg
#   inflating: dataset-original/trash/trash35.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash35.jpg
#   inflating: dataset-original/trash/trash36.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash36.jpg
#   inflating: dataset-original/trash/trash37.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash37.jpg
#   inflating: dataset-original/trash/trash38.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash38.jpg
#   inflating: dataset-original/trash/trash39.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash39.jpg
#   inflating: dataset-original/trash/trash4.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash4.jpg
#   inflating: dataset-original/trash/trash40.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash40.jpg
#   inflating: dataset-original/trash/trash41.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash41.jpg
#   inflating: dataset-original/trash/trash42.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash42.jpg
#   inflating: dataset-original/trash/trash43.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash43.jpg
#   inflating: dataset-original/trash/trash44.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash44.jpg
#   inflating: dataset-original/trash/trash45.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash45.jpg
#   inflating: dataset-original/trash/trash46.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash46.jpg
#   inflating: dataset-original/trash/trash47.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash47.jpg
#   inflating: dataset-original/trash/trash48.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash48.jpg
#   inflating: dataset-original/trash/trash49.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash49.jpg
#   inflating: dataset-original/trash/trash5.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash5.jpg
#   inflating: dataset-original/trash/trash50.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash50.jpg
#   inflating: dataset-original/trash/trash51.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash51.jpg
#   inflating: dataset-original/trash/trash52.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash52.jpg
#   inflating: dataset-original/trash/trash53.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash53.jpg
#   inflating: dataset-original/trash/trash54.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash54.jpg
#   inflating: dataset-original/trash/trash55.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash55.jpg
#   inflating: dataset-original/trash/trash56.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash56.jpg
#   inflating: dataset-original/trash/trash57.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash57.jpg
#   inflating: dataset-original/trash/trash58.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash58.jpg
#   inflating: dataset-original/trash/trash59.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash59.jpg
#   inflating: dataset-original/trash/trash6.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash6.jpg
#   inflating: dataset-original/trash/trash60.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash60.jpg
#   inflating: dataset-original/trash/trash61.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash61.jpg
#   inflating: dataset-original/trash/trash62.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash62.jpg
#   inflating: dataset-original/trash/trash63.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash63.jpg
#   inflating: dataset-original/trash/trash64.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash64.jpg
#   inflating: dataset-original/trash/trash65.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash65.jpg
#   inflating: dataset-original/trash/trash66.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash66.jpg
#   inflating: dataset-original/trash/trash67.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash67.jpg
#   inflating: dataset-original/trash/trash68.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash68.jpg
#   inflating: dataset-original/trash/trash69.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash69.jpg
#   inflating: dataset-original/trash/trash7.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash7.jpg
#   inflating: dataset-original/trash/trash70.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash70.jpg
#   inflating: dataset-original/trash/trash71.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash71.jpg
#   inflating: dataset-original/trash/trash72.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash72.jpg
#   inflating: dataset-original/trash/trash73.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash73.jpg
#   inflating: dataset-original/trash/trash74.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash74.jpg
#   inflating: dataset-original/trash/trash75.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash75.jpg
#   inflating: dataset-original/trash/trash76.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash76.jpg
#   inflating: dataset-original/trash/trash77.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash77.jpg
#   inflating: dataset-original/trash/trash78.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash78.jpg
#   inflating: dataset-original/trash/trash79.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash79.jpg
#   inflating: dataset-original/trash/trash8.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash8.jpg
#   inflating: dataset-original/trash/trash80.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash80.jpg
#   inflating: dataset-original/trash/trash81.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash81.jpg
#   inflating: dataset-original/trash/trash82.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash82.jpg
#   inflating: dataset-original/trash/trash83.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash83.jpg
#   inflating: dataset-original/trash/trash84.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash84.jpg
#   inflating: dataset-original/trash/trash85.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash85.jpg
#   inflating: dataset-original/trash/trash86.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash86.jpg
#   inflating: dataset-original/trash/trash87.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash87.jpg
#   inflating: dataset-original/trash/trash88.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash88.jpg
#   inflating: dataset-original/trash/trash89.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash89.jpg
#   inflating: dataset-original/trash/trash9.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash9.jpg
#   inflating: dataset-original/trash/trash90.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash90.jpg
#   inflating: dataset-original/trash/trash91.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash91.jpg
#   inflating: dataset-original/trash/trash92.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash92.jpg
#   inflating: dataset-original/trash/trash93.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash93.jpg
#   inflating: dataset-original/trash/trash94.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash94.jpg
#   inflating: dataset-original/trash/trash95.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash95.jpg
#   inflating: dataset-original/trash/trash96.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash96.jpg
#   inflating: dataset-original/trash/trash97.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash97.jpg
#   inflating: dataset-original/trash/trash98.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash98.jpg
#   inflating: dataset-original/trash/trash99.jpg
#   inflating: __MACOSX/dataset-original/trash/._trash99.jpg
#   inflating: __MACOSX/dataset-original/._trash
#   inflating: __MACOSX/._dataset-original

# %%
# !unzip /content/drive/MyDrive/trashnet-data/dataset-resized.zip
# Out:
# Archive:  /content/drive/MyDrive/trashnet-data/dataset-resized.zip
#    creating: dataset-resized/
#   inflating: dataset-resized/.DS_Store
#    creating: __MACOSX/
#    creating: __MACOSX/dataset-resized/
#   inflating: __MACOSX/dataset-resized/._.DS_Store
#    creating: dataset-resized/cardboard/
#   inflating: dataset-resized/cardboard/cardboard1.jpg
#   inflating: dataset-resized/cardboard/cardboard10.jpg
#   inflating: dataset-resized/cardboard/cardboard100.jpg
#   inflating: dataset-resized/cardboard/cardboard101.jpg
#   inflating: dataset-resized/cardboard/cardboard102.jpg
#   inflating: dataset-resized/cardboard/cardboard103.jpg
#   inflating: dataset-resized/cardboard/cardboard104.jpg
#   inflating: dataset-resized/cardboard/cardboard105.jpg
#   inflating: dataset-resized/cardboard/cardboard106.jpg
#   inflating: dataset-resized/cardboard/cardboard107.jpg
#   inflating: dataset-resized/cardboard/cardboard108.jpg
#   inflating: dataset-resized/cardboard/cardboard109.jpg
#   inflating: dataset-resized/cardboard/cardboard11.jpg
#   inflating: dataset-resized/cardboard/cardboard110.jpg
#   inflating: dataset-resized/cardboard/cardboard111.jpg
#   inflating: dataset-resized/cardboard/cardboard112.jpg
#   inflating: dataset-resized/cardboard/cardboard113.jpg
#   inflating: dataset-resized/cardboard/cardboard114.jpg
#   inflating: dataset-resized/cardboard/cardboard115.jpg
#   inflating: dataset-resized/cardboard/cardboard116.jpg
#   inflating: dataset-resized/cardboard/cardboard117.jpg
#   inflating: dataset-resized/cardboard/cardboard118.jpg
#   inflating: dataset-resized/cardboard/cardboard119.jpg
#   inflating: dataset-resized/cardboard/cardboard12.jpg
#   inflating: dataset-resized/cardboard/cardboard120.jpg
#   inflating: dataset-resized/cardboard/cardboard121.jpg
#   inflating: dataset-resized/cardboard/cardboard122.jpg
#   inflating: dataset-resized/cardboard/cardboard123.jpg
#   inflating: dataset-resized/cardboard/cardboard124.jpg
#   inflating: dataset-resized/cardboard/cardboard125.jpg
#   inflating: dataset-resized/cardboard/cardboard126.jpg
#   inflating: dataset-resized/cardboard/cardboard127.jpg
#   inflating: dataset-resized/cardboard/cardboard128.jpg
#   inflating: dataset-resized/cardboard/cardboard129.jpg
#   inflating: dataset-resized/cardboard/cardboard13.jpg
#   inflating: dataset-resized/cardboard/cardboard130.jpg
#   inflating: dataset-resized/cardboard/cardboard131.jpg
#   inflating: dataset-resized/cardboard/cardboard132.jpg
#   inflating: dataset-resized/cardboard/cardboard133.jpg
#   inflating: dataset-resized/cardboard/cardboard134.jpg
#   inflating: dataset-resized/cardboard/cardboard135.jpg
#   inflating: dataset-resized/cardboard/cardboard136.jpg
#   inflating: dataset-resized/cardboard/cardboard137.jpg
#   inflating: dataset-resized/cardboard/cardboard138.jpg
#   inflating: dataset-resized/cardboard/cardboard139.jpg
#   inflating: dataset-resized/cardboard/cardboard14.jpg
#   inflating: dataset-resized/cardboard/cardboard140.jpg
#   inflating: dataset-resized/cardboard/cardboard141.jpg
#   inflating: dataset-resized/cardboard/cardboard142.jpg
#   inflating: dataset-resized/cardboard/cardboard143.jpg
#   inflating: dataset-resized/cardboard/cardboard144.jpg
#   inflating: dataset-resized/cardboard/cardboard145.jpg
#   inflating: dataset-resized/cardboard/cardboard146.jpg
#   inflating: dataset-resized/cardboard/cardboard147.jpg
#   inflating: dataset-resized/cardboard/cardboard148.jpg
#   inflating: dataset-resized/cardboard/cardboard149.jpg
#   inflating: dataset-resized/cardboard/cardboard15.jpg
#   inflating: dataset-resized/cardboard/cardboard150.jpg
#   inflating: dataset-resized/cardboard/cardboard151.jpg
#   inflating: dataset-resized/cardboard/cardboard152.jpg
#   inflating: dataset-resized/cardboard/cardboard153.jpg
#   inflating: dataset-resized/cardboard/cardboard154.jpg
#   inflating: dataset-resized/cardboard/cardboard155.jpg
#   inflating: dataset-resized/cardboard/cardboard156.jpg
#   inflating: dataset-resized/cardboard/cardboard157.jpg
#   inflating: dataset-resized/cardboard/cardboard158.jpg
#   inflating: dataset-resized/cardboard/cardboard159.jpg
#   inflating: dataset-resized/cardboard/cardboard16.jpg
#   inflating: dataset-resized/cardboard/cardboard160.jpg
#   inflating: dataset-resized/cardboard/cardboard161.jpg
#   inflating: dataset-resized/cardboard/cardboard162.jpg
#   inflating: dataset-resized/cardboard/cardboard163.jpg
#   inflating: dataset-resized/cardboard/cardboard164.jpg
#   inflating: dataset-resized/cardboard/cardboard165.jpg
#   inflating: dataset-resized/cardboard/cardboard166.jpg
#   inflating: dataset-resized/cardboard/cardboard167.jpg
#   inflating: dataset-resized/cardboard/cardboard168.jpg
#   inflating: dataset-resized/cardboard/cardboard169.jpg
#   inflating: dataset-resized/cardboard/cardboard17.jpg
#   inflating: dataset-resized/cardboard/cardboard170.jpg
#   inflating: dataset-resized/cardboard/cardboard171.jpg
#   inflating: dataset-resized/cardboard/cardboard172.jpg
#   inflating: dataset-resized/cardboard/cardboard173.jpg
#   inflating: dataset-resized/cardboard/cardboard174.jpg
#   inflating: dataset-resized/cardboard/cardboard175.jpg
#   inflating: dataset-resized/cardboard/cardboard176.jpg
#   inflating: dataset-resized/cardboard/cardboard177.jpg
#   inflating: dataset-resized/cardboard/cardboard178.jpg
#   inflating: dataset-resized/cardboard/cardboard179.jpg
#   inflating: dataset-resized/cardboard/cardboard18.jpg
#   inflating: dataset-resized/cardboard/cardboard180.jpg
#   inflating: dataset-resized/cardboard/cardboard181.jpg
#   inflating: dataset-resized/cardboard/cardboard182.jpg
#   inflating: dataset-resized/cardboard/cardboard183.jpg
#   inflating: dataset-resized/cardboard/cardboard184.jpg
#   inflating: dataset-resized/cardboard/cardboard185.jpg
#   inflating: dataset-resized/cardboard/cardboard186.jpg
#   inflating: dataset-resized/cardboard/cardboard187.jpg
#   inflating: dataset-resized/cardboard/cardboard188.jpg
#   inflating: dataset-resized/cardboard/cardboard189.jpg
#   inflating: dataset-resized/cardboard/cardboard19.jpg
#   inflating: dataset-resized/cardboard/cardboard190.jpg
#   inflating: dataset-resized/cardboard/cardboard191.jpg
#   inflating: dataset-resized/cardboard/cardboard192.jpg
#   inflating: dataset-resized/cardboard/cardboard193.jpg
#   inflating: dataset-resized/cardboard/cardboard194.jpg
#   inflating: dataset-resized/cardboard/cardboard195.jpg
#   inflating: dataset-resized/cardboard/cardboard196.jpg
#   inflating: dataset-resized/cardboard/cardboard197.jpg
#   inflating: dataset-resized/cardboard/cardboard198.jpg
#   inflating: dataset-resized/cardboard/cardboard199.jpg
#   inflating: dataset-resized/cardboard/cardboard2.jpg
#   inflating: dataset-resized/cardboard/cardboard20.jpg
#   inflating: dataset-resized/cardboard/cardboard200.jpg
#   inflating: dataset-resized/cardboard/cardboard201.jpg
#   inflating: dataset-resized/cardboard/cardboard202.jpg
#   inflating: dataset-resized/cardboard/cardboard203.jpg
#   inflating: dataset-resized/cardboard/cardboard204.jpg
#   inflating: dataset-resized/cardboard/cardboard205.jpg
#   inflating: dataset-resized/cardboard/cardboard206.jpg
#   inflating: dataset-resized/cardboard/cardboard207.jpg
#   inflating: dataset-resized/cardboard/cardboard208.jpg
#   inflating: dataset-resized/cardboard/cardboard209.jpg
#   inflating: dataset-resized/cardboard/cardboard21.jpg
#   inflating: dataset-resized/cardboard/cardboard210.jpg
#   inflating: dataset-resized/cardboard/cardboard211.jpg
#   inflating: dataset-resized/cardboard/cardboard212.jpg
#   inflating: dataset-resized/cardboard/cardboard213.jpg
#   inflating: dataset-resized/cardboard/cardboard214.jpg
#   inflating: dataset-resized/cardboard/cardboard215.jpg
#   inflating: dataset-resized/cardboard/cardboard216.jpg
#   inflating: dataset-resized/cardboard/cardboard217.jpg
#   inflating: dataset-resized/cardboard/cardboard218.jpg
#   inflating: dataset-resized/cardboard/cardboard219.jpg
#   inflating: dataset-resized/cardboard/cardboard22.jpg
#   inflating: dataset-resized/cardboard/cardboard220.jpg
#   inflating: dataset-resized/cardboard/cardboard221.jpg
#   inflating: dataset-resized/cardboard/cardboard222.jpg
#   inflating: dataset-resized/cardboard/cardboard223.jpg
#   inflating: dataset-resized/cardboard/cardboard224.jpg
#   inflating: dataset-resized/cardboard/cardboard225.jpg
#   inflating: dataset-resized/cardboard/cardboard226.jpg
#   inflating: dataset-resized/cardboard/cardboard227.jpg
#   inflating: dataset-resized/cardboard/cardboard228.jpg
#   inflating: dataset-resized/cardboard/cardboard229.jpg
#   inflating: dataset-resized/cardboard/cardboard23.jpg
#   inflating: dataset-resized/cardboard/cardboard230.jpg
#   inflating: dataset-resized/cardboard/cardboard231.jpg
#   inflating: dataset-resized/cardboard/cardboard232.jpg
#   inflating: dataset-resized/cardboard/cardboard233.jpg
#   inflating: dataset-resized/cardboard/cardboard234.jpg
#   inflating: dataset-resized/cardboard/cardboard235.jpg
#   inflating: dataset-resized/cardboard/cardboard236.jpg
#   inflating: dataset-resized/cardboard/cardboard237.jpg
#   inflating: dataset-resized/cardboard/cardboard238.jpg
#   inflating: dataset-resized/cardboard/cardboard239.jpg
#   inflating: dataset-resized/cardboard/cardboard24.jpg
#   inflating: dataset-resized/cardboard/cardboard240.jpg
#   inflating: dataset-resized/cardboard/cardboard241.jpg
#   inflating: dataset-resized/cardboard/cardboard242.jpg
#   inflating: dataset-resized/cardboard/cardboard243.jpg
#   inflating: dataset-resized/cardboard/cardboard244.jpg
#   inflating: dataset-resized/cardboard/cardboard245.jpg
#   inflating: dataset-resized/cardboard/cardboard246.jpg
#   inflating: dataset-resized/cardboard/cardboard247.jpg
#   inflating: dataset-resized/cardboard/cardboard248.jpg
#   inflating: dataset-resized/cardboard/cardboard249.jpg
#   inflating: dataset-resized/cardboard/cardboard25.jpg
#   inflating: dataset-resized/cardboard/cardboard250.jpg
#   inflating: dataset-resized/cardboard/cardboard251.jpg
#   inflating: dataset-resized/cardboard/cardboard252.jpg
#   inflating: dataset-resized/cardboard/cardboard253.jpg
#   inflating: dataset-resized/cardboard/cardboard254.jpg
#   inflating: dataset-resized/cardboard/cardboard255.jpg
#   inflating: dataset-resized/cardboard/cardboard256.jpg
#   inflating: dataset-resized/cardboard/cardboard257.jpg
#   inflating: dataset-resized/cardboard/cardboard258.jpg
#   inflating: dataset-resized/cardboard/cardboard259.jpg
#   inflating: dataset-resized/cardboard/cardboard26.jpg
#   inflating: dataset-resized/cardboard/cardboard260.jpg
#   inflating: dataset-resized/cardboard/cardboard261.jpg
#   inflating: dataset-resized/cardboard/cardboard262.jpg
#   inflating: dataset-resized/cardboard/cardboard263.jpg
#   inflating: dataset-resized/cardboard/cardboard264.jpg
#   inflating: dataset-resized/cardboard/cardboard265.jpg
#   inflating: dataset-resized/cardboard/cardboard266.jpg
#   inflating: dataset-resized/cardboard/cardboard267.jpg
#   inflating: dataset-resized/cardboard/cardboard268.jpg
#   inflating: dataset-resized/cardboard/cardboard269.jpg
#   inflating: dataset-resized/cardboard/cardboard27.jpg
#   inflating: dataset-resized/cardboard/cardboard270.jpg
#   inflating: dataset-resized/cardboard/cardboard271.jpg
#   inflating: dataset-resized/cardboard/cardboard272.jpg
#   inflating: dataset-resized/cardboard/cardboard273.jpg
#   inflating: dataset-resized/cardboard/cardboard274.jpg
#   inflating: dataset-resized/cardboard/cardboard275.jpg
#   inflating: dataset-resized/cardboard/cardboard276.jpg
#   inflating: dataset-resized/cardboard/cardboard277.jpg
#   inflating: dataset-resized/cardboard/cardboard278.jpg
#   inflating: dataset-resized/cardboard/cardboard279.jpg
#   inflating: dataset-resized/cardboard/cardboard28.jpg
#   inflating: dataset-resized/cardboard/cardboard280.jpg
#   inflating: dataset-resized/cardboard/cardboard281.jpg
#   inflating: dataset-resized/cardboard/cardboard282.jpg
#   inflating: dataset-resized/cardboard/cardboard283.jpg
#   inflating: dataset-resized/cardboard/cardboard284.jpg
#   inflating: dataset-resized/cardboard/cardboard285.jpg
#   inflating: dataset-resized/cardboard/cardboard286.jpg
#   inflating: dataset-resized/cardboard/cardboard287.jpg
#   inflating: dataset-resized/cardboard/cardboard288.jpg
#   inflating: dataset-resized/cardboard/cardboard289.jpg
#   inflating: dataset-resized/cardboard/cardboard29.jpg
#   inflating: dataset-resized/cardboard/cardboard290.jpg
#   inflating: dataset-resized/cardboard/cardboard291.jpg
#   inflating: dataset-resized/cardboard/cardboard292.jpg
#   inflating: dataset-resized/cardboard/cardboard293.jpg
#   inflating: dataset-resized/cardboard/cardboard294.jpg
#   inflating: dataset-resized/cardboard/cardboard295.jpg
#   inflating: dataset-resized/cardboard/cardboard296.jpg
#   inflating: dataset-resized/cardboard/cardboard297.jpg
#   inflating: dataset-resized/cardboard/cardboard298.jpg
#   inflating: dataset-resized/cardboard/cardboard299.jpg
#   inflating: dataset-resized/cardboard/cardboard3.jpg
#   inflating: dataset-resized/cardboard/cardboard30.jpg
#   inflating: dataset-resized/cardboard/cardboard300.jpg
#   inflating: dataset-resized/cardboard/cardboard301.jpg
#   inflating: dataset-resized/cardboard/cardboard302.jpg
#   inflating: dataset-resized/cardboard/cardboard303.jpg
#   inflating: dataset-resized/cardboard/cardboard304.jpg
#   inflating: dataset-resized/cardboard/cardboard305.jpg
#   inflating: dataset-resized/cardboard/cardboard306.jpg
#   inflating: dataset-resized/cardboard/cardboard307.jpg
#   inflating: dataset-resized/cardboard/cardboard308.jpg
#   inflating: dataset-resized/cardboard/cardboard309.jpg
#   inflating: dataset-resized/cardboard/cardboard31.jpg
#   inflating: dataset-resized/cardboard/cardboard310.jpg
#   inflating: dataset-resized/cardboard/cardboard311.jpg
#   inflating: dataset-resized/cardboard/cardboard312.jpg
#   inflating: dataset-resized/cardboard/cardboard313.jpg
#   inflating: dataset-resized/cardboard/cardboard314.jpg
#   inflating: dataset-resized/cardboard/cardboard315.jpg
#   inflating: dataset-resized/cardboard/cardboard316.jpg
#   inflating: dataset-resized/cardboard/cardboard317.jpg
#   inflating: dataset-resized/cardboard/cardboard318.jpg
#   inflating: dataset-resized/cardboard/cardboard319.jpg
#   inflating: dataset-resized/cardboard/cardboard32.jpg
#   inflating: dataset-resized/cardboard/cardboard320.jpg
#   inflating: dataset-resized/cardboard/cardboard321.jpg
#   inflating: dataset-resized/cardboard/cardboard322.jpg
#   inflating: dataset-resized/cardboard/cardboard323.jpg
#   inflating: dataset-resized/cardboard/cardboard324.jpg
#   inflating: dataset-resized/cardboard/cardboard325.jpg
#   inflating: dataset-resized/cardboard/cardboard326.jpg
#   inflating: dataset-resized/cardboard/cardboard327.jpg
#   inflating: dataset-resized/cardboard/cardboard328.jpg
#   inflating: dataset-resized/cardboard/cardboard329.jpg
#   inflating: dataset-resized/cardboard/cardboard33.jpg
#   inflating: dataset-resized/cardboard/cardboard330.jpg
#   inflating: dataset-resized/cardboard/cardboard331.jpg
#   inflating: dataset-resized/cardboard/cardboard332.jpg
#   inflating: dataset-resized/cardboard/cardboard333.jpg
#   inflating: dataset-resized/cardboard/cardboard334.jpg
#   inflating: dataset-resized/cardboard/cardboard335.jpg
#   inflating: dataset-resized/cardboard/cardboard336.jpg
#   inflating: dataset-resized/cardboard/cardboard337.jpg
#   inflating: dataset-resized/cardboard/cardboard338.jpg
#   inflating: dataset-resized/cardboard/cardboard339.jpg
#   inflating: dataset-resized/cardboard/cardboard34.jpg
#   inflating: dataset-resized/cardboard/cardboard340.jpg
#   inflating: dataset-resized/cardboard/cardboard341.jpg
#   inflating: dataset-resized/cardboard/cardboard342.jpg
#   inflating: dataset-resized/cardboard/cardboard343.jpg
#   inflating: dataset-resized/cardboard/cardboard344.jpg
#   inflating: dataset-resized/cardboard/cardboard345.jpg
#   inflating: dataset-resized/cardboard/cardboard346.jpg
#   inflating: dataset-resized/cardboard/cardboard347.jpg
#   inflating: dataset-resized/cardboard/cardboard348.jpg
#   inflating: dataset-resized/cardboard/cardboard349.jpg
#   inflating: dataset-resized/cardboard/cardboard35.jpg
#   inflating: dataset-resized/cardboard/cardboard350.jpg
#   inflating: dataset-resized/cardboard/cardboard351.jpg
#   inflating: dataset-resized/cardboard/cardboard352.jpg
#   inflating: dataset-resized/cardboard/cardboard353.jpg
#   inflating: dataset-resized/cardboard/cardboard354.jpg
#   inflating: dataset-resized/cardboard/cardboard355.jpg
#   inflating: dataset-resized/cardboard/cardboard356.jpg
#   inflating: dataset-resized/cardboard/cardboard357.jpg
#   inflating: dataset-resized/cardboard/cardboard358.jpg
#   inflating: dataset-resized/cardboard/cardboard359.jpg
#   inflating: dataset-resized/cardboard/cardboard36.jpg
#   inflating: dataset-resized/cardboard/cardboard360.jpg
#   inflating: dataset-resized/cardboard/cardboard361.jpg
#   inflating: dataset-resized/cardboard/cardboard362.jpg
#   inflating: dataset-resized/cardboard/cardboard363.jpg
#   inflating: dataset-resized/cardboard/cardboard364.jpg
#   inflating: dataset-resized/cardboard/cardboard365.jpg
#   inflating: dataset-resized/cardboard/cardboard366.jpg
#   inflating: dataset-resized/cardboard/cardboard367.jpg
#   inflating: dataset-resized/cardboard/cardboard368.jpg
#   inflating: dataset-resized/cardboard/cardboard369.jpg
#   inflating: dataset-resized/cardboard/cardboard37.jpg
#   inflating: dataset-resized/cardboard/cardboard370.jpg
#   inflating: dataset-resized/cardboard/cardboard371.jpg
#   inflating: dataset-resized/cardboard/cardboard372.jpg
#   inflating: dataset-resized/cardboard/cardboard373.jpg
#   inflating: dataset-resized/cardboard/cardboard374.jpg
#   inflating: dataset-resized/cardboard/cardboard375.jpg
#   inflating: dataset-resized/cardboard/cardboard376.jpg
#   inflating: dataset-resized/cardboard/cardboard377.jpg
#   inflating: dataset-resized/cardboard/cardboard378.jpg
#   inflating: dataset-resized/cardboard/cardboard379.jpg
#   inflating: dataset-resized/cardboard/cardboard38.jpg
#   inflating: dataset-resized/cardboard/cardboard380.jpg
#   inflating: dataset-resized/cardboard/cardboard381.jpg
#   inflating: dataset-resized/cardboard/cardboard382.jpg
#   inflating: dataset-resized/cardboard/cardboard383.jpg
#   inflating: dataset-resized/cardboard/cardboard384.jpg
#   inflating: dataset-resized/cardboard/cardboard385.jpg
#   inflating: dataset-resized/cardboard/cardboard386.jpg
#   inflating: dataset-resized/cardboard/cardboard387.jpg
#   inflating: dataset-resized/cardboard/cardboard388.jpg
#   inflating: dataset-resized/cardboard/cardboard389.jpg
#   inflating: dataset-resized/cardboard/cardboard39.jpg
#   inflating: dataset-resized/cardboard/cardboard390.jpg
#   inflating: dataset-resized/cardboard/cardboard391.jpg
#   inflating: dataset-resized/cardboard/cardboard392.jpg
#   inflating: dataset-resized/cardboard/cardboard393.jpg
#   inflating: dataset-resized/cardboard/cardboard394.jpg
#   inflating: dataset-resized/cardboard/cardboard395.jpg
#   inflating: dataset-resized/cardboard/cardboard396.jpg
#   inflating: dataset-resized/cardboard/cardboard397.jpg
#   inflating: dataset-resized/cardboard/cardboard398.jpg
#   inflating: dataset-resized/cardboard/cardboard399.jpg
#   inflating: dataset-resized/cardboard/cardboard4.jpg
#   inflating: dataset-resized/cardboard/cardboard40.jpg
#   inflating: dataset-resized/cardboard/cardboard400.jpg
#   inflating: dataset-resized/cardboard/cardboard401.jpg
#   inflating: dataset-resized/cardboard/cardboard402.jpg
#   inflating: dataset-resized/cardboard/cardboard403.jpg
#   inflating: dataset-resized/cardboard/cardboard41.jpg
#   inflating: dataset-resized/cardboard/cardboard42.jpg
#   inflating: dataset-resized/cardboard/cardboard43.jpg
#   inflating: dataset-resized/cardboard/cardboard44.jpg
#   inflating: dataset-resized/cardboard/cardboard45.jpg
#   inflating: dataset-resized/cardboard/cardboard46.jpg
#   inflating: dataset-resized/cardboard/cardboard47.jpg
#   inflating: dataset-resized/cardboard/cardboard48.jpg
#   inflating: dataset-resized/cardboard/cardboard49.jpg
#   inflating: dataset-resized/cardboard/cardboard5.jpg
#   inflating: dataset-resized/cardboard/cardboard50.jpg
#   inflating: dataset-resized/cardboard/cardboard51.jpg
#   inflating: dataset-resized/cardboard/cardboard52.jpg
#   inflating: dataset-resized/cardboard/cardboard53.jpg
#   inflating: dataset-resized/cardboard/cardboard54.jpg
#   inflating: dataset-resized/cardboard/cardboard55.jpg
#   inflating: dataset-resized/cardboard/cardboard56.jpg
#   inflating: dataset-resized/cardboard/cardboard57.jpg
#   inflating: dataset-resized/cardboard/cardboard58.jpg
#   inflating: dataset-resized/cardboard/cardboard59.jpg
#   inflating: dataset-resized/cardboard/cardboard6.jpg
#   inflating: dataset-resized/cardboard/cardboard60.jpg
#   inflating: dataset-resized/cardboard/cardboard61.jpg
#   inflating: dataset-resized/cardboard/cardboard62.jpg
#   inflating: dataset-resized/cardboard/cardboard63.jpg
#   inflating: dataset-resized/cardboard/cardboard64.jpg
#   inflating: dataset-resized/cardboard/cardboard65.jpg
#   inflating: dataset-resized/cardboard/cardboard66.jpg
#   inflating: dataset-resized/cardboard/cardboard67.jpg
#   inflating: dataset-resized/cardboard/cardboard68.jpg
#   inflating: dataset-resized/cardboard/cardboard69.jpg
#   inflating: dataset-resized/cardboard/cardboard7.jpg
#   inflating: dataset-resized/cardboard/cardboard70.jpg
#   inflating: dataset-resized/cardboard/cardboard71.jpg
#   inflating: dataset-resized/cardboard/cardboard72.jpg
#   inflating: dataset-resized/cardboard/cardboard73.jpg
#   inflating: dataset-resized/cardboard/cardboard74.jpg
#   inflating: dataset-resized/cardboard/cardboard75.jpg
#   inflating: dataset-resized/cardboard/cardboard76.jpg
#   inflating: dataset-resized/cardboard/cardboard77.jpg
#   inflating: dataset-resized/cardboard/cardboard78.jpg
#   inflating: dataset-resized/cardboard/cardboard79.jpg
#   inflating: dataset-resized/cardboard/cardboard8.jpg
#   inflating: dataset-resized/cardboard/cardboard80.jpg
#   inflating: dataset-resized/cardboard/cardboard81.jpg
#   inflating: dataset-resized/cardboard/cardboard82.jpg
#   inflating: dataset-resized/cardboard/cardboard83.jpg
#   inflating: dataset-resized/cardboard/cardboard84.jpg
#   inflating: dataset-resized/cardboard/cardboard85.jpg
#   inflating: dataset-resized/cardboard/cardboard86.jpg
#   inflating: dataset-resized/cardboard/cardboard87.jpg
#   inflating: dataset-resized/cardboard/cardboard88.jpg
#   inflating: dataset-resized/cardboard/cardboard89.jpg
#   inflating: dataset-resized/cardboard/cardboard9.jpg
#    creating: __MACOSX/dataset-resized/cardboard/
#   inflating: __MACOSX/dataset-resized/cardboard/._cardboard9.jpg
#   inflating: dataset-resized/cardboard/cardboard90.jpg
#   inflating: dataset-resized/cardboard/cardboard91.jpg
#   inflating: dataset-resized/cardboard/cardboard92.jpg
#   inflating: dataset-resized/cardboard/cardboard93.jpg
#   inflating: dataset-resized/cardboard/cardboard94.jpg
#   inflating: dataset-resized/cardboard/cardboard95.jpg
#   inflating: dataset-resized/cardboard/cardboard96.jpg
#   inflating: dataset-resized/cardboard/cardboard97.jpg
#   inflating: dataset-resized/cardboard/cardboard98.jpg
#   inflating: dataset-resized/cardboard/cardboard99.jpg
#    creating: dataset-resized/glass/
#   inflating: dataset-resized/glass/glass1.jpg
#   inflating: dataset-resized/glass/glass10.jpg
#   inflating: dataset-resized/glass/glass100.jpg
#   inflating: dataset-resized/glass/glass101.jpg
#   inflating: dataset-resized/glass/glass102.jpg
#   inflating: dataset-resized/glass/glass103.jpg
#   inflating: dataset-resized/glass/glass104.jpg
#   inflating: dataset-resized/glass/glass105.jpg
#   inflating: dataset-resized/glass/glass106.jpg
#   inflating: dataset-resized/glass/glass107.jpg
#   inflating: dataset-resized/glass/glass108.jpg
#   inflating: dataset-resized/glass/glass109.jpg
#   inflating: dataset-resized/glass/glass11.jpg
#   inflating: dataset-resized/glass/glass110.jpg
#   inflating: dataset-resized/glass/glass111.jpg
#   inflating: dataset-resized/glass/glass112.jpg
#   inflating: dataset-resized/glass/glass113.jpg
#   inflating: dataset-resized/glass/glass114.jpg
#   inflating: dataset-resized/glass/glass115.jpg
#   inflating: dataset-resized/glass/glass116.jpg
#   inflating: dataset-resized/glass/glass117.jpg
#   inflating: dataset-resized/glass/glass118.jpg
#   inflating: dataset-resized/glass/glass119.jpg
#   inflating: dataset-resized/glass/glass12.jpg
#   inflating: dataset-resized/glass/glass120.jpg
#   inflating: dataset-resized/glass/glass121.jpg
#   inflating: dataset-resized/glass/glass122.jpg
#   inflating: dataset-resized/glass/glass123.jpg
#   inflating: dataset-resized/glass/glass124.jpg
#   inflating: dataset-resized/glass/glass125.jpg
#   inflating: dataset-resized/glass/glass126.jpg
#   inflating: dataset-resized/glass/glass127.jpg
#   inflating: dataset-resized/glass/glass128.jpg
#   inflating: dataset-resized/glass/glass129.jpg
#   inflating: dataset-resized/glass/glass13.jpg
#   inflating: dataset-resized/glass/glass130.jpg
#   inflating: dataset-resized/glass/glass131.jpg
#   inflating: dataset-resized/glass/glass132.jpg
#   inflating: dataset-resized/glass/glass133.jpg
#   inflating: dataset-resized/glass/glass134.jpg
#   inflating: dataset-resized/glass/glass135.jpg
#   inflating: dataset-resized/glass/glass136.jpg
#   inflating: dataset-resized/glass/glass137.jpg
#   inflating: dataset-resized/glass/glass138.jpg
#   inflating: dataset-resized/glass/glass139.jpg
#   inflating: dataset-resized/glass/glass14.jpg
#   inflating: dataset-resized/glass/glass140.jpg
#   inflating: dataset-resized/glass/glass141.jpg
#   inflating: dataset-resized/glass/glass142.jpg
#   inflating: dataset-resized/glass/glass143.jpg
#   inflating: dataset-resized/glass/glass144.jpg
#   inflating: dataset-resized/glass/glass145.jpg
#   inflating: dataset-resized/glass/glass146.jpg
#   inflating: dataset-resized/glass/glass147.jpg
#   inflating: dataset-resized/glass/glass148.jpg
#   inflating: dataset-resized/glass/glass149.jpg
#   inflating: dataset-resized/glass/glass15.jpg
#   inflating: dataset-resized/glass/glass150.jpg
#   inflating: dataset-resized/glass/glass151.jpg
#   inflating: dataset-resized/glass/glass152.jpg
#   inflating: dataset-resized/glass/glass153.jpg
#   inflating: dataset-resized/glass/glass154.jpg
#   inflating: dataset-resized/glass/glass155.jpg
#   inflating: dataset-resized/glass/glass156.jpg
#   inflating: dataset-resized/glass/glass157.jpg
#   inflating: dataset-resized/glass/glass158.jpg
#   inflating: dataset-resized/glass/glass159.jpg
#   inflating: dataset-resized/glass/glass16.jpg
#   inflating: dataset-resized/glass/glass160.jpg
#   inflating: dataset-resized/glass/glass161.jpg
#   inflating: dataset-resized/glass/glass162.jpg
#   inflating: dataset-resized/glass/glass163.jpg
#   inflating: dataset-resized/glass/glass164.jpg
#   inflating: dataset-resized/glass/glass165.jpg
#   inflating: dataset-resized/glass/glass166.jpg
#   inflating: dataset-resized/glass/glass167.jpg
#   inflating: dataset-resized/glass/glass168.jpg
#   inflating: dataset-resized/glass/glass169.jpg
#   inflating: dataset-resized/glass/glass17.jpg
#   inflating: dataset-resized/glass/glass170.jpg
#   inflating: dataset-resized/glass/glass171.jpg
#   inflating: dataset-resized/glass/glass172.jpg
#   inflating: dataset-resized/glass/glass173.jpg
#   inflating: dataset-resized/glass/glass174.jpg
#   inflating: dataset-resized/glass/glass175.jpg
#   inflating: dataset-resized/glass/glass176.jpg
#   inflating: dataset-resized/glass/glass177.jpg
#   inflating: dataset-resized/glass/glass178.jpg
#   inflating: dataset-resized/glass/glass179.jpg
#   inflating: dataset-resized/glass/glass18.jpg
#   inflating: dataset-resized/glass/glass180.jpg
#   inflating: dataset-resized/glass/glass181.jpg
#   inflating: dataset-resized/glass/glass182.jpg
#   inflating: dataset-resized/glass/glass183.jpg
#   inflating: dataset-resized/glass/glass184.jpg
#   inflating: dataset-resized/glass/glass185.jpg
#   inflating: dataset-resized/glass/glass186.jpg
#   inflating: dataset-resized/glass/glass187.jpg
#   inflating: dataset-resized/glass/glass188.jpg
#   inflating: dataset-resized/glass/glass189.jpg
#   inflating: dataset-resized/glass/glass19.jpg
#   inflating: dataset-resized/glass/glass190.jpg
#   inflating: dataset-resized/glass/glass191.jpg
#   inflating: dataset-resized/glass/glass192.jpg
#   inflating: dataset-resized/glass/glass193.jpg
#   inflating: dataset-resized/glass/glass194.jpg
#   inflating: dataset-resized/glass/glass195.jpg
#   inflating: dataset-resized/glass/glass196.jpg
#   inflating: dataset-resized/glass/glass197.jpg
#   inflating: dataset-resized/glass/glass198.jpg
#   inflating: dataset-resized/glass/glass199.jpg
#   inflating: dataset-resized/glass/glass2.jpg
#   inflating: dataset-resized/glass/glass20.jpg
#   inflating: dataset-resized/glass/glass200.jpg
#   inflating: dataset-resized/glass/glass201.jpg
#   inflating: dataset-resized/glass/glass202.jpg
#   inflating: dataset-resized/glass/glass203.jpg
#   inflating: dataset-resized/glass/glass204.jpg
#   inflating: dataset-resized/glass/glass205.jpg
#   inflating: dataset-resized/glass/glass206.jpg
#   inflating: dataset-resized/glass/glass207.jpg
#   inflating: dataset-resized/glass/glass208.jpg
#   inflating: dataset-resized/glass/glass209.jpg
#   inflating: dataset-resized/glass/glass21.jpg
#   inflating: dataset-resized/glass/glass210.jpg
#   inflating: dataset-resized/glass/glass211.jpg
#   inflating: dataset-resized/glass/glass212.jpg
#   inflating: dataset-resized/glass/glass213.jpg
#   inflating: dataset-resized/glass/glass214.jpg
#   inflating: dataset-resized/glass/glass215.jpg
#   inflating: dataset-resized/glass/glass216.jpg
#   inflating: dataset-resized/glass/glass217.jpg
#   inflating: dataset-resized/glass/glass218.jpg
#   inflating: dataset-resized/glass/glass219.jpg
#   inflating: dataset-resized/glass/glass22.jpg
#   inflating: dataset-resized/glass/glass220.jpg
#   inflating: dataset-resized/glass/glass221.jpg
#   inflating: dataset-resized/glass/glass222.jpg
#   inflating: dataset-resized/glass/glass223.jpg
#   inflating: dataset-resized/glass/glass224.jpg
#   inflating: dataset-resized/glass/glass225.jpg
#   inflating: dataset-resized/glass/glass226.jpg
#   inflating: dataset-resized/glass/glass227.jpg
#   inflating: dataset-resized/glass/glass228.jpg
#   inflating: dataset-resized/glass/glass229.jpg
#   inflating: dataset-resized/glass/glass23.jpg
#   inflating: dataset-resized/glass/glass230.jpg
#   inflating: dataset-resized/glass/glass231.jpg
#   inflating: dataset-resized/glass/glass232.jpg
#   inflating: dataset-resized/glass/glass233.jpg
#   inflating: dataset-resized/glass/glass234.jpg
#   inflating: dataset-resized/glass/glass235.jpg
#   inflating: dataset-resized/glass/glass236.jpg
#   inflating: dataset-resized/glass/glass237.jpg
#   inflating: dataset-resized/glass/glass238.jpg
#   inflating: dataset-resized/glass/glass239.jpg
#   inflating: dataset-resized/glass/glass24.jpg
#   inflating: dataset-resized/glass/glass240.jpg
#   inflating: dataset-resized/glass/glass241.jpg
#   inflating: dataset-resized/glass/glass242.jpg
#   inflating: dataset-resized/glass/glass243.jpg
#   inflating: dataset-resized/glass/glass244.jpg
#   inflating: dataset-resized/glass/glass245.jpg
#   inflating: dataset-resized/glass/glass246.jpg
#   inflating: dataset-resized/glass/glass247.jpg
#   inflating: dataset-resized/glass/glass248.jpg
#   inflating: dataset-resized/glass/glass249.jpg
#   inflating: dataset-resized/glass/glass25.jpg
#   inflating: dataset-resized/glass/glass250.jpg
#   inflating: dataset-resized/glass/glass251.jpg
#   inflating: dataset-resized/glass/glass252.jpg
#   inflating: dataset-resized/glass/glass253.jpg
#   inflating: dataset-resized/glass/glass254.jpg
#   inflating: dataset-resized/glass/glass255.jpg
#   inflating: dataset-resized/glass/glass256.jpg
#   inflating: dataset-resized/glass/glass257.jpg
#   inflating: dataset-resized/glass/glass258.jpg
#   inflating: dataset-resized/glass/glass259.jpg
#   inflating: dataset-resized/glass/glass26.jpg
#   inflating: dataset-resized/glass/glass260.jpg
#   inflating: dataset-resized/glass/glass261.jpg
#   inflating: dataset-resized/glass/glass262.jpg
#   inflating: dataset-resized/glass/glass263.jpg
#   inflating: dataset-resized/glass/glass264.jpg
#   inflating: dataset-resized/glass/glass265.jpg
#   inflating: dataset-resized/glass/glass266.jpg
#   inflating: dataset-resized/glass/glass267.jpg
#   inflating: dataset-resized/glass/glass268.jpg
#   inflating: dataset-resized/glass/glass269.jpg
#   inflating: dataset-resized/glass/glass27.jpg
#   inflating: dataset-resized/glass/glass270.jpg
#   inflating: dataset-resized/glass/glass271.jpg
#   inflating: dataset-resized/glass/glass272.jpg
#   inflating: dataset-resized/glass/glass273.jpg
#   inflating: dataset-resized/glass/glass274.jpg
#   inflating: dataset-resized/glass/glass275.jpg
#   inflating: dataset-resized/glass/glass276.jpg
#   inflating: dataset-resized/glass/glass277.jpg
#   inflating: dataset-resized/glass/glass278.jpg
#   inflating: dataset-resized/glass/glass279.jpg
#   inflating: dataset-resized/glass/glass28.jpg
#   inflating: dataset-resized/glass/glass280.jpg
#   inflating: dataset-resized/glass/glass281.jpg
#   inflating: dataset-resized/glass/glass282.jpg
#   inflating: dataset-resized/glass/glass283.jpg
#   inflating: dataset-resized/glass/glass284.jpg
#   inflating: dataset-resized/glass/glass285.jpg
#   inflating: dataset-resized/glass/glass286.jpg
#   inflating: dataset-resized/glass/glass287.jpg
#   inflating: dataset-resized/glass/glass288.jpg
#   inflating: dataset-resized/glass/glass289.jpg
#   inflating: dataset-resized/glass/glass29.jpg
#   inflating: dataset-resized/glass/glass290.jpg
#   inflating: dataset-resized/glass/glass291.jpg
#   inflating: dataset-resized/glass/glass292.jpg
#   inflating: dataset-resized/glass/glass293.jpg
#   inflating: dataset-resized/glass/glass294.jpg
#   inflating: dataset-resized/glass/glass295.jpg
#   inflating: dataset-resized/glass/glass296.jpg
#   inflating: dataset-resized/glass/glass297.jpg
#   inflating: dataset-resized/glass/glass298.jpg
#   inflating: dataset-resized/glass/glass299.jpg
#   inflating: dataset-resized/glass/glass3.jpg
#   inflating: dataset-resized/glass/glass30.jpg
#   inflating: dataset-resized/glass/glass300.jpg
#   inflating: dataset-resized/glass/glass301.jpg
#   inflating: dataset-resized/glass/glass302.jpg
#   inflating: dataset-resized/glass/glass303.jpg
#   inflating: dataset-resized/glass/glass304.jpg
#   inflating: dataset-resized/glass/glass305.jpg
#   inflating: dataset-resized/glass/glass306.jpg
#   inflating: dataset-resized/glass/glass307.jpg
#   inflating: dataset-resized/glass/glass308.jpg
#   inflating: dataset-resized/glass/glass309.jpg
#   inflating: dataset-resized/glass/glass31.jpg
#   inflating: dataset-resized/glass/glass310.jpg
#   inflating: dataset-resized/glass/glass311.jpg
#   inflating: dataset-resized/glass/glass312.jpg
#   inflating: dataset-resized/glass/glass313.jpg
#   inflating: dataset-resized/glass/glass314.jpg
#   inflating: dataset-resized/glass/glass315.jpg
#   inflating: dataset-resized/glass/glass316.jpg
#   inflating: dataset-resized/glass/glass317.jpg
#   inflating: dataset-resized/glass/glass318.jpg
#   inflating: dataset-resized/glass/glass319.jpg
#   inflating: dataset-resized/glass/glass32.jpg
#   inflating: dataset-resized/glass/glass320.jpg
#   inflating: dataset-resized/glass/glass321.jpg
#   inflating: dataset-resized/glass/glass322.jpg
#   inflating: dataset-resized/glass/glass323.jpg
#   inflating: dataset-resized/glass/glass324.jpg
#   inflating: dataset-resized/glass/glass325.jpg
#   inflating: dataset-resized/glass/glass326.jpg
#   inflating: dataset-resized/glass/glass327.jpg
#   inflating: dataset-resized/glass/glass328.jpg
#   inflating: dataset-resized/glass/glass329.jpg
#   inflating: dataset-resized/glass/glass33.jpg
#   inflating: dataset-resized/glass/glass330.jpg
#   inflating: dataset-resized/glass/glass331.jpg
#   inflating: dataset-resized/glass/glass332.jpg
#   inflating: dataset-resized/glass/glass333.jpg
#   inflating: dataset-resized/glass/glass334.jpg
#   inflating: dataset-resized/glass/glass335.jpg
#   inflating: dataset-resized/glass/glass336.jpg
#   inflating: dataset-resized/glass/glass337.jpg
#   inflating: dataset-resized/glass/glass338.jpg
#   inflating: dataset-resized/glass/glass339.jpg
#   inflating: dataset-resized/glass/glass34.jpg
#   inflating: dataset-resized/glass/glass340.jpg
#   inflating: dataset-resized/glass/glass341.jpg
#   inflating: dataset-resized/glass/glass342.jpg
#   inflating: dataset-resized/glass/glass343.jpg
#   inflating: dataset-resized/glass/glass344.jpg
#   inflating: dataset-resized/glass/glass345.jpg
#   inflating: dataset-resized/glass/glass346.jpg
#   inflating: dataset-resized/glass/glass347.jpg
#   inflating: dataset-resized/glass/glass348.jpg
#   inflating: dataset-resized/glass/glass349.jpg
#   inflating: dataset-resized/glass/glass35.jpg
#   inflating: dataset-resized/glass/glass350.jpg
#   inflating: dataset-resized/glass/glass351.jpg
#   inflating: dataset-resized/glass/glass352.jpg
#   inflating: dataset-resized/glass/glass353.jpg
#   inflating: dataset-resized/glass/glass354.jpg
#   inflating: dataset-resized/glass/glass355.jpg
#   inflating: dataset-resized/glass/glass356.jpg
#   inflating: dataset-resized/glass/glass357.jpg
#   inflating: dataset-resized/glass/glass358.jpg
#   inflating: dataset-resized/glass/glass359.jpg
#   inflating: dataset-resized/glass/glass36.jpg
#   inflating: dataset-resized/glass/glass360.jpg
#   inflating: dataset-resized/glass/glass361.jpg
#   inflating: dataset-resized/glass/glass362.jpg
#   inflating: dataset-resized/glass/glass363.jpg
#   inflating: dataset-resized/glass/glass364.jpg
#   inflating: dataset-resized/glass/glass365.jpg
#   inflating: dataset-resized/glass/glass366.jpg
#   inflating: dataset-resized/glass/glass367.jpg
#   inflating: dataset-resized/glass/glass368.jpg
#   inflating: dataset-resized/glass/glass369.jpg
#   inflating: dataset-resized/glass/glass37.jpg
#   inflating: dataset-resized/glass/glass370.jpg
#   inflating: dataset-resized/glass/glass371.jpg
#   inflating: dataset-resized/glass/glass372.jpg
#   inflating: dataset-resized/glass/glass373.jpg
#   inflating: dataset-resized/glass/glass374.jpg
#   inflating: dataset-resized/glass/glass375.jpg
#   inflating: dataset-resized/glass/glass376.jpg
#   inflating: dataset-resized/glass/glass377.jpg
#   inflating: dataset-resized/glass/glass378.jpg
#   inflating: dataset-resized/glass/glass379.jpg
#   inflating: dataset-resized/glass/glass38.jpg
#   inflating: dataset-resized/glass/glass380.jpg
#   inflating: dataset-resized/glass/glass381.jpg
#   inflating: dataset-resized/glass/glass382.jpg
#   inflating: dataset-resized/glass/glass383.jpg
#   inflating: dataset-resized/glass/glass384.jpg
#   inflating: dataset-resized/glass/glass385.jpg
#   inflating: dataset-resized/glass/glass386.jpg
#   inflating: dataset-resized/glass/glass387.jpg
#   inflating: dataset-resized/glass/glass388.jpg
#   inflating: dataset-resized/glass/glass389.jpg
#   inflating: dataset-resized/glass/glass39.jpg
#   inflating: dataset-resized/glass/glass390.jpg
#   inflating: dataset-resized/glass/glass391.jpg
#   inflating: dataset-resized/glass/glass392.jpg
#   inflating: dataset-resized/glass/glass393.jpg
#   inflating: dataset-resized/glass/glass394.jpg
#   inflating: dataset-resized/glass/glass395.jpg
#   inflating: dataset-resized/glass/glass396.jpg
#   inflating: dataset-resized/glass/glass397.jpg
#   inflating: dataset-resized/glass/glass398.jpg
#   inflating: dataset-resized/glass/glass399.jpg
#   inflating: dataset-resized/glass/glass4.jpg
#   inflating: dataset-resized/glass/glass40.jpg
#   inflating: dataset-resized/glass/glass400.jpg
#   inflating: dataset-resized/glass/glass401.jpg
#   inflating: dataset-resized/glass/glass402.jpg
#   inflating: dataset-resized/glass/glass403.jpg
#   inflating: dataset-resized/glass/glass404.jpg
#   inflating: dataset-resized/glass/glass405.jpg
#   inflating: dataset-resized/glass/glass406.jpg
#   inflating: dataset-resized/glass/glass407.jpg
#   inflating: dataset-resized/glass/glass408.jpg
#   inflating: dataset-resized/glass/glass409.jpg
#   inflating: dataset-resized/glass/glass41.jpg
#   inflating: dataset-resized/glass/glass410.jpg
#   inflating: dataset-resized/glass/glass411.jpg
#   inflating: dataset-resized/glass/glass412.jpg
#   inflating: dataset-resized/glass/glass413.jpg
#   inflating: dataset-resized/glass/glass414.jpg
#   inflating: dataset-resized/glass/glass415.jpg
#   inflating: dataset-resized/glass/glass416.jpg
#   inflating: dataset-resized/glass/glass417.jpg
#   inflating: dataset-resized/glass/glass418.jpg
#   inflating: dataset-resized/glass/glass419.jpg
#   inflating: dataset-resized/glass/glass42.jpg
#   inflating: dataset-resized/glass/glass420.jpg
#   inflating: dataset-resized/glass/glass421.jpg
#   inflating: dataset-resized/glass/glass422.jpg
#   inflating: dataset-resized/glass/glass423.jpg
#   inflating: dataset-resized/glass/glass424.jpg
#   inflating: dataset-resized/glass/glass425.jpg
#   inflating: dataset-resized/glass/glass426.jpg
#   inflating: dataset-resized/glass/glass427.jpg
#   inflating: dataset-resized/glass/glass428.jpg
#   inflating: dataset-resized/glass/glass429.jpg
#   inflating: dataset-resized/glass/glass43.jpg
#   inflating: dataset-resized/glass/glass430.jpg
#   inflating: dataset-resized/glass/glass431.jpg
#   inflating: dataset-resized/glass/glass432.jpg
#   inflating: dataset-resized/glass/glass433.jpg
#   inflating: dataset-resized/glass/glass434.jpg
#   inflating: dataset-resized/glass/glass435.jpg
#   inflating: dataset-resized/glass/glass436.jpg
#   inflating: dataset-resized/glass/glass437.jpg
#   inflating: dataset-resized/glass/glass438.jpg
#   inflating: dataset-resized/glass/glass439.jpg
#   inflating: dataset-resized/glass/glass44.jpg
#   inflating: dataset-resized/glass/glass440.jpg
#   inflating: dataset-resized/glass/glass441.jpg
#   inflating: dataset-resized/glass/glass442.jpg
#   inflating: dataset-resized/glass/glass443.jpg
#   inflating: dataset-resized/glass/glass444.jpg
#   inflating: dataset-resized/glass/glass445.jpg
#   inflating: dataset-resized/glass/glass446.jpg
#   inflating: dataset-resized/glass/glass447.jpg
#   inflating: dataset-resized/glass/glass448.jpg
#   inflating: dataset-resized/glass/glass449.jpg
#   inflating: dataset-resized/glass/glass45.jpg
#   inflating: dataset-resized/glass/glass450.jpg
#   inflating: dataset-resized/glass/glass451.jpg
#   inflating: dataset-resized/glass/glass452.jpg
#   inflating: dataset-resized/glass/glass453.jpg
#   inflating: dataset-resized/glass/glass454.jpg
#   inflating: dataset-resized/glass/glass455.jpg
#   inflating: dataset-resized/glass/glass456.jpg
#   inflating: dataset-resized/glass/glass457.jpg
#   inflating: dataset-resized/glass/glass458.jpg
#   inflating: dataset-resized/glass/glass459.jpg
#   inflating: dataset-resized/glass/glass46.jpg
#   inflating: dataset-resized/glass/glass460.jpg
#   inflating: dataset-resized/glass/glass461.jpg
#   inflating: dataset-resized/glass/glass462.jpg
#   inflating: dataset-resized/glass/glass463.jpg
#   inflating: dataset-resized/glass/glass464.jpg
#   inflating: dataset-resized/glass/glass465.jpg
#   inflating: dataset-resized/glass/glass466.jpg
#   inflating: dataset-resized/glass/glass467.jpg
#   inflating: dataset-resized/glass/glass468.jpg
#   inflating: dataset-resized/glass/glass469.jpg
#   inflating: dataset-resized/glass/glass47.jpg
#   inflating: dataset-resized/glass/glass470.jpg
#   inflating: dataset-resized/glass/glass471.jpg
#   inflating: dataset-resized/glass/glass472.jpg
#   inflating: dataset-resized/glass/glass473.jpg
#   inflating: dataset-resized/glass/glass474.jpg
#   inflating: dataset-resized/glass/glass475.jpg
#   inflating: dataset-resized/glass/glass476.jpg
#   inflating: dataset-resized/glass/glass477.jpg
#   inflating: dataset-resized/glass/glass478.jpg
#   inflating: dataset-resized/glass/glass479.jpg
#   inflating: dataset-resized/glass/glass48.jpg
#   inflating: dataset-resized/glass/glass480.jpg
#   inflating: dataset-resized/glass/glass481.jpg
#   inflating: dataset-resized/glass/glass482.jpg
#   inflating: dataset-resized/glass/glass483.jpg
#   inflating: dataset-resized/glass/glass484.jpg
#   inflating: dataset-resized/glass/glass485.jpg
#   inflating: dataset-resized/glass/glass486.jpg
#   inflating: dataset-resized/glass/glass487.jpg
#   inflating: dataset-resized/glass/glass488.jpg
#   inflating: dataset-resized/glass/glass489.jpg
#   inflating: dataset-resized/glass/glass49.jpg
#   inflating: dataset-resized/glass/glass490.jpg
#   inflating: dataset-resized/glass/glass491.jpg
#   inflating: dataset-resized/glass/glass492.jpg
#   inflating: dataset-resized/glass/glass493.jpg
#   inflating: dataset-resized/glass/glass494.jpg
#   inflating: dataset-resized/glass/glass495.jpg
#   inflating: dataset-resized/glass/glass496.jpg
#   inflating: dataset-resized/glass/glass497.jpg
#   inflating: dataset-resized/glass/glass498.jpg
#   inflating: dataset-resized/glass/glass499.jpg
#   inflating: dataset-resized/glass/glass5.jpg
#   inflating: dataset-resized/glass/glass50.jpg
#   inflating: dataset-resized/glass/glass500.jpg
#   inflating: dataset-resized/glass/glass501.jpg
#   inflating: dataset-resized/glass/glass51.jpg
#   inflating: dataset-resized/glass/glass52.jpg
#   inflating: dataset-resized/glass/glass53.jpg
#   inflating: dataset-resized/glass/glass54.jpg
#   inflating: dataset-resized/glass/glass55.jpg
#   inflating: dataset-resized/glass/glass56.jpg
#   inflating: dataset-resized/glass/glass57.jpg
#   inflating: dataset-resized/glass/glass58.jpg
#   inflating: dataset-resized/glass/glass59.jpg
#   inflating: dataset-resized/glass/glass6.jpg
#   inflating: dataset-resized/glass/glass60.jpg
#   inflating: dataset-resized/glass/glass61.jpg
#   inflating: dataset-resized/glass/glass62.jpg
#   inflating: dataset-resized/glass/glass63.jpg
#   inflating: dataset-resized/glass/glass64.jpg
#   inflating: dataset-resized/glass/glass65.jpg
#   inflating: dataset-resized/glass/glass66.jpg
#   inflating: dataset-resized/glass/glass67.jpg
#   inflating: dataset-resized/glass/glass68.jpg
#   inflating: dataset-resized/glass/glass69.jpg
#   inflating: dataset-resized/glass/glass7.jpg
#   inflating: dataset-resized/glass/glass70.jpg
#   inflating: dataset-resized/glass/glass71.jpg
#   inflating: dataset-resized/glass/glass72.jpg
#   inflating: dataset-resized/glass/glass73.jpg
#   inflating: dataset-resized/glass/glass74.jpg
#   inflating: dataset-resized/glass/glass75.jpg
#   inflating: dataset-resized/glass/glass76.jpg
#   inflating: dataset-resized/glass/glass77.jpg
#   inflating: dataset-resized/glass/glass78.jpg
#   inflating: dataset-resized/glass/glass79.jpg
#   inflating: dataset-resized/glass/glass8.jpg
#   inflating: dataset-resized/glass/glass80.jpg
#   inflating: dataset-resized/glass/glass81.jpg
#   inflating: dataset-resized/glass/glass82.jpg
#   inflating: dataset-resized/glass/glass83.jpg
#   inflating: dataset-resized/glass/glass84.jpg
#   inflating: dataset-resized/glass/glass85.jpg
#   inflating: dataset-resized/glass/glass86.jpg
# ...
#   inflating: dataset-resized/plastic/plastic379.jpg
#   inflating: dataset-resized/plastic/plastic38.jpg
#   inflating: dataset-resized/plastic/plastic380.jpg
#   inflating: dataset-resized/plastic/plastic381.jpg
#   inflating: dataset-resized/plastic/plastic382.jpg
#   inflating: dataset-resized/plastic/plastic383.jpg
#   inflating: dataset-resized/plastic/plastic384.jpg
#   inflating: dataset-resized/plastic/plastic385.jpg
#   inflating: dataset-resized/plastic/plastic386.jpg
#   inflating: dataset-resized/plastic/plastic387.jpg
#   inflating: dataset-resized/plastic/plastic388.jpg
#   inflating: dataset-resized/plastic/plastic389.jpg
#   inflating: dataset-resized/plastic/plastic39.jpg
#   inflating: dataset-resized/plastic/plastic390.jpg
#   inflating: dataset-resized/plastic/plastic391.jpg
#   inflating: dataset-resized/plastic/plastic392.jpg
#   inflating: dataset-resized/plastic/plastic393.jpg
#   inflating: dataset-resized/plastic/plastic394.jpg
#   inflating: dataset-resized/plastic/plastic395.jpg
#   inflating: dataset-resized/plastic/plastic396.jpg
#   inflating: dataset-resized/plastic/plastic397.jpg
#   inflating: dataset-resized/plastic/plastic398.jpg
#   inflating: dataset-resized/plastic/plastic399.jpg
#   inflating: dataset-resized/plastic/plastic4.jpg
#   inflating: dataset-resized/plastic/plastic40.jpg
#   inflating: dataset-resized/plastic/plastic400.jpg
#   inflating: dataset-resized/plastic/plastic401.jpg
#   inflating: dataset-resized/plastic/plastic402.jpg
#   inflating: dataset-resized/plastic/plastic403.jpg
#   inflating: dataset-resized/plastic/plastic404.jpg
#   inflating: dataset-resized/plastic/plastic405.jpg
#   inflating: dataset-resized/plastic/plastic406.jpg
#   inflating: dataset-resized/plastic/plastic407.jpg
#   inflating: dataset-resized/plastic/plastic408.jpg
#   inflating: dataset-resized/plastic/plastic409.jpg
#   inflating: dataset-resized/plastic/plastic41.jpg
#   inflating: dataset-resized/plastic/plastic410.jpg
#   inflating: dataset-resized/plastic/plastic411.jpg
#   inflating: dataset-resized/plastic/plastic412.jpg
#   inflating: dataset-resized/plastic/plastic413.jpg
#   inflating: dataset-resized/plastic/plastic414.jpg
#   inflating: dataset-resized/plastic/plastic415.jpg
#   inflating: dataset-resized/plastic/plastic416.jpg
#   inflating: dataset-resized/plastic/plastic417.jpg
#   inflating: dataset-resized/plastic/plastic418.jpg
#   inflating: dataset-resized/plastic/plastic419.jpg
#   inflating: dataset-resized/plastic/plastic42.jpg
#   inflating: dataset-resized/plastic/plastic420.jpg
#   inflating: dataset-resized/plastic/plastic421.jpg
#   inflating: dataset-resized/plastic/plastic422.jpg
#   inflating: dataset-resized/plastic/plastic423.jpg
#   inflating: dataset-resized/plastic/plastic424.jpg
#   inflating: dataset-resized/plastic/plastic425.jpg
#   inflating: dataset-resized/plastic/plastic426.jpg
#   inflating: dataset-resized/plastic/plastic427.jpg
#   inflating: dataset-resized/plastic/plastic428.jpg
#   inflating: dataset-resized/plastic/plastic429.jpg
#   inflating: dataset-resized/plastic/plastic43.jpg
#   inflating: dataset-resized/plastic/plastic430.jpg
#   inflating: dataset-resized/plastic/plastic431.jpg
#   inflating: dataset-resized/plastic/plastic432.jpg
#   inflating: dataset-resized/plastic/plastic433.jpg
#   inflating: dataset-resized/plastic/plastic434.jpg
#   inflating: dataset-resized/plastic/plastic435.jpg
#   inflating: dataset-resized/plastic/plastic436.jpg
#   inflating: dataset-resized/plastic/plastic437.jpg
#   inflating: dataset-resized/plastic/plastic438.jpg
#   inflating: dataset-resized/plastic/plastic439.jpg
#   inflating: dataset-resized/plastic/plastic44.jpg
#   inflating: dataset-resized/plastic/plastic440.jpg
#   inflating: dataset-resized/plastic/plastic441.jpg
#   inflating: dataset-resized/plastic/plastic442.jpg
#   inflating: dataset-resized/plastic/plastic443.jpg
#   inflating: dataset-resized/plastic/plastic444.jpg
#   inflating: dataset-resized/plastic/plastic445.jpg
#   inflating: dataset-resized/plastic/plastic446.jpg
#   inflating: dataset-resized/plastic/plastic447.jpg
#   inflating: dataset-resized/plastic/plastic448.jpg
#   inflating: dataset-resized/plastic/plastic449.jpg
#   inflating: dataset-resized/plastic/plastic45.jpg
#   inflating: dataset-resized/plastic/plastic450.jpg
#   inflating: dataset-resized/plastic/plastic451.jpg
#   inflating: dataset-resized/plastic/plastic452.jpg
#   inflating: dataset-resized/plastic/plastic453.jpg
#   inflating: dataset-resized/plastic/plastic454.jpg
#   inflating: dataset-resized/plastic/plastic455.jpg
#   inflating: dataset-resized/plastic/plastic456.jpg
#   inflating: dataset-resized/plastic/plastic457.jpg
#   inflating: dataset-resized/plastic/plastic458.jpg
#   inflating: dataset-resized/plastic/plastic459.jpg
#   inflating: dataset-resized/plastic/plastic46.jpg
#   inflating: dataset-resized/plastic/plastic460.jpg
#   inflating: dataset-resized/plastic/plastic461.jpg
#   inflating: dataset-resized/plastic/plastic462.jpg
#   inflating: dataset-resized/plastic/plastic463.jpg
#   inflating: dataset-resized/plastic/plastic464.jpg
#   inflating: dataset-resized/plastic/plastic465.jpg
#   inflating: dataset-resized/plastic/plastic466.jpg
#   inflating: dataset-resized/plastic/plastic467.jpg
#   inflating: dataset-resized/plastic/plastic468.jpg
#   inflating: dataset-resized/plastic/plastic469.jpg
#   inflating: dataset-resized/plastic/plastic47.jpg
#   inflating: dataset-resized/plastic/plastic470.jpg
#   inflating: dataset-resized/plastic/plastic471.jpg
#   inflating: dataset-resized/plastic/plastic472.jpg
#   inflating: dataset-resized/plastic/plastic473.jpg
#   inflating: dataset-resized/plastic/plastic474.jpg
#   inflating: dataset-resized/plastic/plastic475.jpg
#   inflating: dataset-resized/plastic/plastic476.jpg
#   inflating: dataset-resized/plastic/plastic477.jpg
#   inflating: dataset-resized/plastic/plastic478.jpg
#   inflating: dataset-resized/plastic/plastic479.jpg
#   inflating: dataset-resized/plastic/plastic48.jpg
#   inflating: dataset-resized/plastic/plastic480.jpg
#   inflating: dataset-resized/plastic/plastic481.jpg
#   inflating: dataset-resized/plastic/plastic482.jpg
#   inflating: dataset-resized/plastic/plastic49.jpg
#   inflating: dataset-resized/plastic/plastic5.jpg
#   inflating: dataset-resized/plastic/plastic50.jpg
#   inflating: dataset-resized/plastic/plastic51.jpg
#   inflating: dataset-resized/plastic/plastic52.jpg
#   inflating: dataset-resized/plastic/plastic53.jpg
#   inflating: dataset-resized/plastic/plastic54.jpg
#   inflating: dataset-resized/plastic/plastic55.jpg
#   inflating: dataset-resized/plastic/plastic56.jpg
#   inflating: dataset-resized/plastic/plastic57.jpg
#   inflating: dataset-resized/plastic/plastic58.jpg
#   inflating: dataset-resized/plastic/plastic59.jpg
#   inflating: dataset-resized/plastic/plastic6.jpg
#   inflating: dataset-resized/plastic/plastic60.jpg
#   inflating: dataset-resized/plastic/plastic61.jpg
#   inflating: dataset-resized/plastic/plastic62.jpg
#   inflating: dataset-resized/plastic/plastic63.jpg
#   inflating: dataset-resized/plastic/plastic64.jpg
#   inflating: dataset-resized/plastic/plastic65.jpg
#   inflating: dataset-resized/plastic/plastic66.jpg
#   inflating: dataset-resized/plastic/plastic67.jpg
#   inflating: dataset-resized/plastic/plastic68.jpg
#   inflating: dataset-resized/plastic/plastic69.jpg
#   inflating: dataset-resized/plastic/plastic7.jpg
#   inflating: dataset-resized/plastic/plastic70.jpg
#   inflating: dataset-resized/plastic/plastic71.jpg
#   inflating: dataset-resized/plastic/plastic72.jpg
#   inflating: dataset-resized/plastic/plastic73.jpg
#   inflating: dataset-resized/plastic/plastic74.jpg
#   inflating: dataset-resized/plastic/plastic75.jpg
#   inflating: dataset-resized/plastic/plastic76.jpg
#   inflating: dataset-resized/plastic/plastic77.jpg
#   inflating: dataset-resized/plastic/plastic78.jpg
#   inflating: dataset-resized/plastic/plastic79.jpg
#   inflating: dataset-resized/plastic/plastic8.jpg
#   inflating: dataset-resized/plastic/plastic80.jpg
#   inflating: dataset-resized/plastic/plastic81.jpg
#   inflating: dataset-resized/plastic/plastic82.jpg
#   inflating: dataset-resized/plastic/plastic83.jpg
#   inflating: dataset-resized/plastic/plastic84.jpg
#   inflating: dataset-resized/plastic/plastic85.jpg
#   inflating: dataset-resized/plastic/plastic86.jpg
#   inflating: dataset-resized/plastic/plastic87.jpg
#   inflating: dataset-resized/plastic/plastic88.jpg
#   inflating: dataset-resized/plastic/plastic89.jpg
#   inflating: dataset-resized/plastic/plastic9.jpg
#   inflating: dataset-resized/plastic/plastic90.jpg
#   inflating: dataset-resized/plastic/plastic91.jpg
#   inflating: dataset-resized/plastic/plastic92.jpg
#   inflating: dataset-resized/plastic/plastic93.jpg
#   inflating: dataset-resized/plastic/plastic94.jpg
#   inflating: dataset-resized/plastic/plastic95.jpg
#   inflating: dataset-resized/plastic/plastic96.jpg
#   inflating: dataset-resized/plastic/plastic97.jpg
#   inflating: dataset-resized/plastic/plastic98.jpg
#   inflating: dataset-resized/plastic/plastic99.jpg
#    creating: dataset-resized/trash/
#   inflating: dataset-resized/trash/trash1.jpg
#   inflating: dataset-resized/trash/trash10.jpg
#   inflating: dataset-resized/trash/trash100.jpg
#   inflating: dataset-resized/trash/trash101.jpg
#   inflating: dataset-resized/trash/trash102.jpg
#   inflating: dataset-resized/trash/trash103.jpg
#   inflating: dataset-resized/trash/trash104.jpg
#   inflating: dataset-resized/trash/trash105.jpg
#   inflating: dataset-resized/trash/trash106.jpg
#   inflating: dataset-resized/trash/trash107.jpg
#   inflating: dataset-resized/trash/trash108.jpg
#   inflating: dataset-resized/trash/trash109.jpg
#   inflating: dataset-resized/trash/trash11.jpg
#   inflating: dataset-resized/trash/trash110.jpg
#   inflating: dataset-resized/trash/trash111.jpg
#   inflating: dataset-resized/trash/trash112.jpg
#   inflating: dataset-resized/trash/trash113.jpg
#   inflating: dataset-resized/trash/trash114.jpg
#   inflating: dataset-resized/trash/trash115.jpg
#   inflating: dataset-resized/trash/trash116.jpg
#   inflating: dataset-resized/trash/trash117.jpg
#   inflating: dataset-resized/trash/trash118.jpg
#   inflating: dataset-resized/trash/trash119.jpg
#   inflating: dataset-resized/trash/trash12.jpg
#   inflating: dataset-resized/trash/trash120.jpg
#   inflating: dataset-resized/trash/trash121.jpg
#   inflating: dataset-resized/trash/trash122.jpg
#   inflating: dataset-resized/trash/trash123.jpg
#   inflating: dataset-resized/trash/trash124.jpg
#   inflating: dataset-resized/trash/trash125.jpg
#   inflating: dataset-resized/trash/trash126.jpg
#   inflating: dataset-resized/trash/trash127.jpg
#   inflating: dataset-resized/trash/trash128.jpg
#   inflating: dataset-resized/trash/trash129.jpg
#   inflating: dataset-resized/trash/trash13.jpg
#   inflating: dataset-resized/trash/trash130.jpg
#   inflating: dataset-resized/trash/trash131.jpg
#   inflating: dataset-resized/trash/trash132.jpg
#   inflating: dataset-resized/trash/trash133.jpg
#   inflating: dataset-resized/trash/trash134.jpg
#   inflating: dataset-resized/trash/trash135.jpg
#   inflating: dataset-resized/trash/trash136.jpg
#   inflating: dataset-resized/trash/trash137.jpg
#   inflating: dataset-resized/trash/trash14.jpg
#   inflating: dataset-resized/trash/trash15.jpg
#   inflating: dataset-resized/trash/trash16.jpg
#   inflating: dataset-resized/trash/trash17.jpg
#   inflating: dataset-resized/trash/trash18.jpg
#   inflating: dataset-resized/trash/trash19.jpg
#   inflating: dataset-resized/trash/trash2.jpg
#   inflating: dataset-resized/trash/trash20.jpg
#   inflating: dataset-resized/trash/trash21.jpg
#   inflating: dataset-resized/trash/trash22.jpg
#   inflating: dataset-resized/trash/trash23.jpg
#   inflating: dataset-resized/trash/trash24.jpg
#   inflating: dataset-resized/trash/trash25.jpg
#   inflating: dataset-resized/trash/trash26.jpg
#   inflating: dataset-resized/trash/trash27.jpg
#   inflating: dataset-resized/trash/trash28.jpg
#   inflating: dataset-resized/trash/trash29.jpg
#   inflating: dataset-resized/trash/trash3.jpg
#   inflating: dataset-resized/trash/trash30.jpg
#   inflating: dataset-resized/trash/trash31.jpg
#   inflating: dataset-resized/trash/trash32.jpg
#   inflating: dataset-resized/trash/trash33.jpg
#   inflating: dataset-resized/trash/trash34.jpg
#   inflating: dataset-resized/trash/trash35.jpg
#   inflating: dataset-resized/trash/trash36.jpg
#   inflating: dataset-resized/trash/trash37.jpg
#   inflating: dataset-resized/trash/trash38.jpg
#   inflating: dataset-resized/trash/trash39.jpg
#   inflating: dataset-resized/trash/trash4.jpg
#   inflating: dataset-resized/trash/trash40.jpg
#   inflating: dataset-resized/trash/trash41.jpg
#   inflating: dataset-resized/trash/trash42.jpg
#   inflating: dataset-resized/trash/trash43.jpg
#   inflating: dataset-resized/trash/trash44.jpg
#   inflating: dataset-resized/trash/trash45.jpg
#   inflating: dataset-resized/trash/trash46.jpg
#   inflating: dataset-resized/trash/trash47.jpg
#   inflating: dataset-resized/trash/trash48.jpg
#   inflating: dataset-resized/trash/trash49.jpg
#   inflating: dataset-resized/trash/trash5.jpg
#   inflating: dataset-resized/trash/trash50.jpg
#   inflating: dataset-resized/trash/trash51.jpg
#   inflating: dataset-resized/trash/trash52.jpg
#   inflating: dataset-resized/trash/trash53.jpg
#   inflating: dataset-resized/trash/trash54.jpg
#   inflating: dataset-resized/trash/trash55.jpg
#   inflating: dataset-resized/trash/trash56.jpg
#   inflating: dataset-resized/trash/trash57.jpg
#   inflating: dataset-resized/trash/trash58.jpg
#   inflating: dataset-resized/trash/trash59.jpg
#   inflating: dataset-resized/trash/trash6.jpg
#   inflating: dataset-resized/trash/trash60.jpg
#   inflating: dataset-resized/trash/trash61.jpg
#   inflating: dataset-resized/trash/trash62.jpg
#   inflating: dataset-resized/trash/trash63.jpg
#   inflating: dataset-resized/trash/trash64.jpg
#   inflating: dataset-resized/trash/trash65.jpg
#   inflating: dataset-resized/trash/trash66.jpg
#   inflating: dataset-resized/trash/trash67.jpg
#   inflating: dataset-resized/trash/trash68.jpg
#   inflating: dataset-resized/trash/trash69.jpg
#   inflating: dataset-resized/trash/trash7.jpg
#   inflating: dataset-resized/trash/trash70.jpg
#   inflating: dataset-resized/trash/trash71.jpg
#   inflating: dataset-resized/trash/trash72.jpg
#   inflating: dataset-resized/trash/trash73.jpg
#   inflating: dataset-resized/trash/trash74.jpg
#   inflating: dataset-resized/trash/trash75.jpg
#   inflating: dataset-resized/trash/trash76.jpg
#   inflating: dataset-resized/trash/trash77.jpg
#   inflating: dataset-resized/trash/trash78.jpg
#   inflating: dataset-resized/trash/trash79.jpg
#   inflating: dataset-resized/trash/trash8.jpg
#   inflating: dataset-resized/trash/trash80.jpg
#   inflating: dataset-resized/trash/trash81.jpg
#   inflating: dataset-resized/trash/trash82.jpg
#   inflating: dataset-resized/trash/trash83.jpg
#   inflating: dataset-resized/trash/trash84.jpg
#   inflating: dataset-resized/trash/trash85.jpg
#   inflating: dataset-resized/trash/trash86.jpg
#   inflating: dataset-resized/trash/trash87.jpg
#   inflating: dataset-resized/trash/trash88.jpg
#   inflating: dataset-resized/trash/trash89.jpg
#   inflating: dataset-resized/trash/trash9.jpg
#   inflating: dataset-resized/trash/trash90.jpg
#   inflating: dataset-resized/trash/trash91.jpg
#   inflating: dataset-resized/trash/trash92.jpg
#   inflating: dataset-resized/trash/trash93.jpg
#   inflating: dataset-resized/trash/trash94.jpg
#   inflating: dataset-resized/trash/trash95.jpg
#   inflating: dataset-resized/trash/trash96.jpg
#   inflating: dataset-resized/trash/trash97.jpg
#   inflating: dataset-resized/trash/trash98.jpg
#   inflating: dataset-resized/trash/trash99.jpg

# %% [markdown]
# Preprocess :

# %%
import os
import constants
import numpy as np
from scipy import misc, ndimage

def resize(image, dim1, dim2):
	return misc.imresize(image, (dim1, dim2))

def fileWalk(directory, destPath):
	try: 
		os.makedirs(destPath)
	except OSError:
		if not os.path.isdir(destPath):
			raise

	for subdir, dirs, files in os.walk(directory):
		for file in files:
			if len(file) <= 4 or file[-4:] != '.jpg':
				continue

			pic = misc.imread(os.path.join(subdir, file))
			dim1 = len(pic)
			dim2 = len(pic[0])
			if dim1 > dim2:
				pic = np.rot90(pic)

			picResized = resize(pic,constants.DIM1, constants.DIM2)
			misc.imsave(os.path.join(destPath, file), picResized)
		

def main():
	prepath = os.path.join(os.getcwd(), 'dataset-original')
	glassDir = os.path.join(prepath, 'glass')
	paperDir = os.path.join(prepath, 'paper')
	cardboardDir = os.path.join(prepath, 'cardboard')
	plasticDir = os.path.join(prepath, 'plastic')
	metalDir = os.path.join(prepath, 'metal')
	trashDir = os.path.join(prepath, 'trash')

	destPath = os.path.join(os.getcwd(), 'dataset-resized')
	try: 
		os.makedirs(destPath)
	except OSError:
		if not os.path.isdir(destPath):
			raise

	#GLASS
	fileWalk(glassDir, os.path.join(destPath, 'glass'))

	#PAPER
	fileWalk(paperDir, os.path.join(destPath, 'paper'))

	#CARDBOARD
	fileWalk(cardboardDir, os.path.join(destPath, 'cardboard'))

	#PLASTIC
	fileWalk(plasticDir, os.path.join(destPath, 'plastic'))

	#METAL
	fileWalk(metalDir, os.path.join(destPath, 'metal'))

	#TRASH
	fileWalk(trashDir, os.path.join(destPath, 'trash'))  

if __name__ == '__main__':
    main()

# %% [markdown]
# # plastic : 3 :version : 0.3 : success

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
import pathlib
data_dir = '/content/dataset-resized'
data_dir = pathlib.Path(data_dir)

# %%
imagecount = len(list(data_dir.glob('*/*.jpg')))
print(imagecount)
# Out:
# 2527

# %%
plastic = list(data_dir.glob('plastic/*'))
PIL.Image.open(str(plastic[0]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x384 at 0x7F9505A19290>

# %%
batch_size = 32
img_ht = 180
img_wd = 180

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(data_dir,validation_split=0.2,subset="training",seed=123,image_size=(img_ht,img_wd),batch_size=batch_size)
# Out:
# Found 2527 files belonging to 6 classes.
# Using 2022 files for training.

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_ht, img_wd),
  batch_size=batch_size)
# Out:
# Found 2527 files belonging to 6 classes.
# Using 505 files for validation.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['cardboard', 'glass', 'metal', 'paper', 'plastic', 'trash']

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
for image_batch , label_batch in train_ds:
  print(image_batch.shape)
  print(label_batch.shape)
  break
# Out:
# (32, 180, 180, 3)
# (32,)

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
normalization_layer = layers.Rescaling(1./255)

# %%
normalize_ds = train_ds.map(lambda x,y:(normalization_layer(x),y))
image_batch , label_batch = next(iter(normalize_ds))
first_image = image_batch[0]

print(np.min(first_image),np.max(first_image))
# Out:
# 0.048497714 0.96248364

# %% [markdown]
# NN_Model :

# %%
num_classes = len(class_names)

model = Sequential([
                    layers.Rescaling(1./255,input_shape=(img_ht,img_wd,3)),
                    layers.Conv2D(16,3,padding='same',activation='relu'),
                    layers.MaxPool2D(),
                    layers.Conv2D(32,3,padding='same',activation='sigmoid'),
                    layers.MaxPool2D(),
                    layers.Conv2D(64,3,padding='same',activation='relu'),
                    layers.MaxPooling2D(),
                    layers.Flatten(),
                    layers.Dense(128,activation='relu'),
                    layers.Dense(num_classes)

]
    
)

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
epochs=10
history = model.fit(train_ds,validation_data=val_ds,epochs=epochs)
# Out:
# Epoch 1/10
# 64/64 [==============================] - 13s 64ms/step - loss: 2.2915 - accuracy: 0.2062 - val_loss: 1.7398 - val_accuracy: 0.2455
# Epoch 2/10
# 64/64 [==============================] - 3s 46ms/step - loss: 1.7300 - accuracy: 0.2324 - val_loss: 1.7265 - val_accuracy: 0.2455
# Epoch 3/10
# 64/64 [==============================] - 3s 44ms/step - loss: 1.7285 - accuracy: 0.2260 - val_loss: 1.7325 - val_accuracy: 0.2455
# Epoch 4/10
# 64/64 [==============================] - 3s 44ms/step - loss: 1.7276 - accuracy: 0.2324 - val_loss: 1.7268 - val_accuracy: 0.2455
# Epoch 5/10
# 64/64 [==============================] - 3s 44ms/step - loss: 1.7223 - accuracy: 0.2324 - val_loss: 1.7219 - val_accuracy: 0.2455
# Epoch 6/10
# 64/64 [==============================] - 3s 44ms/step - loss: 1.7185 - accuracy: 0.2324 - val_loss: 1.7106 - val_accuracy: 0.2455
# Epoch 7/10
# 64/64 [==============================] - 3s 45ms/step - loss: 1.7026 - accuracy: 0.2364 - val_loss: 1.6887 - val_accuracy: 0.3208
# Epoch 8/10
# 64/64 [==============================] - 3s 44ms/step - loss: 1.6285 - accuracy: 0.3294 - val_loss: 1.5577 - val_accuracy: 0.4020
# Epoch 9/10
# 64/64 [==============================] - 3s 44ms/step - loss: 1.4211 - accuracy: 0.4189 - val_loss: 1.4967 - val_accuracy: 0.4040
# Epoch 10/10
# 64/64 [==============================] - 3s 45ms/step - loss: 1.3461 - accuracy: 0.4505 - val_loss: 1.3012 - val_accuracy: 0.4812

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
##plastic = list(data_dir.glob('plastic/*'))
PIL.Image.open(str(sunflower_url))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x500 at 0x7F948A263690>

# %%
#prediction 1
sample = "/content/sample.jpg"
#sample_path = tf.keras.utils.get_file('Red_sunflower', origin=sunflower_url)

img = tf.keras.utils.load_img(
    sunflower_url, target_size=(img_ht, img_wd)
)
img_array = tf.keras.utils.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)
# Out:
# This image most likely belongs to plastic with a 65.66 percent confidence.

# %% [markdown]
# #   Reference Links 🐮
# *   https://github.com/anujeet98/plastic-waste-detection
# *   https://github.com/IBM/PlasticNet
# *   https://github.com/antiplasti/Plastic-Detection-Model
# *   https://github.com/garythung/trashnet
# *   https://github.com/moneshj/litter-detection-tensorflow/tree/master/dataset
# *   https://github.com/VinAIResearch/plasticbag-faster-rcnn

# %% [markdown]
# # Extra chatBOT

# %%
# !pip install chatterbot
# Out:
# Collecting chatterbot
#   Downloading ChatterBot-1.0.8-py2.py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 1.6 MB/s
# Collecting sqlalchemy<1.4,>=1.3
#   Downloading SQLAlchemy-1.3.24-cp37-cp37m-manylinux2010_x86_64.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 11.6 MB/s
# Requirement already satisfied: python-dateutil<2.9,>=2.8 in /usr/local/lib/python3.7/dist-packages (from chatterbot) (2.8.2)
# Collecting mathparse<0.2,>=0.1
#   Downloading mathparse-0.1.2-py3-none-any.whl (7.2 kB)
# Requirement already satisfied: pytz in /usr/local/lib/python3.7/dist-packages (from chatterbot) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil<2.9,>=2.8->chatterbot) (1.15.0)
# Installing collected packages: sqlalchemy, mathparse, chatterbot
#   Attempting uninstall: sqlalchemy
#     Found existing installation: SQLAlchemy 1.4.31
#     Uninstalling SQLAlchemy-1.4.31:
#       Successfully uninstalled SQLAlchemy-1.4.31
# Successfully installed chatterbot-1.0.8 mathparse-0.1.2 sqlalchemy-1.3.24

# %%
from chatterbot import ChatBot
from chatterbot.trainers import ListTrainer

# Create a new chat bot named monesh
chatbot = ChatBot('monesh')

trainer = ListTrainer(chatbot)

trainer.train([
    "Hi, can I help you?",
    "Sure, I'd like to book a flight to Iceland.",
    "Your flight has been booked."
])

# Get a response to the input text 'I would like to book a flight.'
response = chatbot.get_response('I would like to book a flight.')

print(response)
# Out:
# List Trainer: [####################] 100%
# Your flight has been booked.

# %%
print(chatbot.get_response('Hi, can I help you?'))
# Out:
# Sure, I'd like to book a flight to Iceland.
